# %%
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
print(gensim.__version__)
# Out:
# 4.2.0

# %%
# STEP 1: load Note datasets
df = pd.read_csv('data/filtered.csv')

# %%
df.head()
# Out:
#    subject_id  hadm_id  icustay_id  expire_flag  \
# 0         291   125726      275109            0
# 1         291   125726      275109            0
# 2         422   117029      299666            0
# 3         671   126769      246119            0
# 4         698   171990      229997            0
#
#                                                 text
# 0  Briefly this is a 72 year old woman with prior...
# 1  Briefly this is a 72 year old woman with prior...
# 2  Pt is a 57 y/p male with h/o afib, LE edema, w...
# 3  Pt admitted from ED at 0530, upon which he was...
# 4  89 year old patient admitted from the EW with ...

# %%
messages=df.filter(items=['expire_flag','text' ])
messages.columns = ["label", "text"]
messages.head()
# Out:
#    label                                               text
# 0      0  Briefly this is a 72 year old woman with prior...
# 1      0  Briefly this is a 72 year old woman with prior...
# 2      0  Pt is a 57 y/p male with h/o afib, LE edema, w...
# 3      0  Pt admitted from ED at 0530, upon which he was...
# 4      0  89 year old patient admitted from the EW with ...

# %%
messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))

# %%
messages.head()
# Out:
#    label                                               text  \
# 0      0  Briefly this is a 72 year old woman with prior...
# 1      0  Briefly this is a 72 year old woman with prior...
# 2      0  Pt is a 57 y/p male with h/o afib, LE edema, w...
# 3      0  Pt admitted from ED at 0530, upon which he was...
# 4      0  89 year old patient admitted from the EW with ...
#
#                                           text_clean
# 0  [briefly, this, is, year, old, woman, with, pr...
# 1  [briefly, this, is, year, old, woman, with, pr...
# 2  [pt, is, male, with, afib, le, edema, who, pre...
# 3  [pt, admitted, from, ed, at, upon, which, he, ...
# 4  [year, old, patient, admitted, from, the, ew, ...

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

X_train
# Out:
# 124      [pt, with, known, cad, now, with, recurrent, a...
# 12996    [age, over, yo, with, cad, cabg, in, and, hosp...
# 4305     [patient, is, admitted, from, outside, hospita...
# 373      [yo, ma, presented, to, hospital, location, un...
# 684      [see, fhp, for, full, pmh, pt, is, yr, old, wo...
# 11919    [hpi, yom, acute, onset, sided, weakness, flac...
# 2970     [the, patient, was, discharged, yesterday, fro...
# 432      [with, history, of, cerebral, palsy, bilateral...
# 2942     [yo, motorcycle, crash, vs, pole, no, helmet, ...
# 8991     [yo, female, with, history, of, colon, ca, pre...
# 12084    [cc, abdominal, pain, at, ventral, hernia, hpi...
# 9589     [this, yr, old, cantonese, speaking, woman, wa...
# 1865     [pt, admitted, after, having, sudden, onset, o...
# 5775     [year, old, male, with, past, alzheimer, and, ...
# 9051     [pt, yo, male, with, pmh, dm, insulin, imi, wi...
# 7490     [pt, found, down, by, neighbor, brought, to, n...
# 9017     [aortic, dissection, assessment, weaned, off, ...
# 2060     [pt, is, yo, male, who, complains, of, an, epi...
# 13109    [patient, present, at, primary, md, first, nam...
# 1220     [hpi, yo, gastric, bypass, at, nwh, with, ugi,...
# 3319     [this, is, year, old, female, with, past, medi...
# 5945     [yo, female, admitted, this, dx, of, brain, ma...
# 7099     [atrial, fibrillation, afib, long, standing, y...
# 6263     [this, is, year, old, man, with, history, of, ...
# 13775    [gout, meningioma, and, wegeners, admitted, to...
# 1124     [heart, failure, chf, diastolic, acute, on, ch...
# 6946     [yo, with, recent, admission, hospital, for, l...
# 6495     [pt, is, an, you, old, male, admitted, to, hos...
# 150      [altered, mental, status, not, delirium, asses...
# 8354     [year, old, male, with, metastatic, melanoma, ...
#                                ...
# 2273     [coronary, artery, bypass, graft, cabg, assess...
# 3328     [title, russian, speaking, male, with, sudden,...
# 781      [pneumonia, bacterial, hospital, acquired, non...
# 13465    [myocardial, infarction, acute, ami, stemi, ns...
# 5915     [assessment, plan, male, with, history, of, me...
# 12505    [trauma, assessment, mvc, pt, came, back, from...
# 7234     [hx, of, crypotegnic, cirrhosis, meld, with, v...
# 13050    [atrial, fibrillation, paroxysmal, with, dccv,...
# 6658     [valve, replacement, aortic, bioprosthetic, av...
# 2308     [male, cabg, lima, lad, svg, om, svg, om, svg,...
# 8989     [yo, russian, speaking, male, admitted, via, e...
# 11770    [sicu, admission, note, patient, arrived, to, ...
# 10729    [patient, is, with, pmhx, sig, for, dm, htn, r...
# 9659     [title, cancer, malignant, neoplasm, stomach, ...
# 5847     [respiratory, failure, acute, not, ards, docto...
# 1984     [pt, is, male, known, as, and, ao, aneurysm, w...
# 9726     [yo, with, copd, on, at, baseline, obesity, dm...
# 13052    [atrial, fibrillation, paroxysmal, with, dccv,...
# 12161    [male, admitted, from, ew, today, acute, abdom...
# 13964    [pt, cleaning, gutter, over, porch, fell, from...
# 8845     [patient, admitted, from, osh, intubated, per,...
# 3766     [yr, old, woman, admitted, from, osh, gallston...
# 8838     [yo, male, with, mds, on, decitabine, recently...
# 2877     [initials, namepattern, last, name, namepatter...
# 11110    [this, yr, old, woman, was, transferred, from,...
# 12999    [mr, known, lastname, is, transferred, from, h...
# 2184                                            [dnr, dni]
# 10057    [admission, and, progress, note, pmh, gi, blee...
# 981      [crohn, involving, sb, and, colon, sb, resecti...
# 5456     [restrained, driver, head, on, collsion, rib, ...
# Name: text_clean, Length: 11268, dtype: object

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=300,window=5,
                                   min_count=2,sg = 1)

# %%
w2v_model.wv.most_similar('managing') 
print(len(X_train))
# Out:
# 11268

# %%
words = set(w2v_model.wv.index_to_key)

# %%
print(words)
# Out:
# {'intepreter', 'vhpi', 'ssent', 'end', 'oddly', 'marked', 'exc', 'mix', 'redrawn', 'bms', 'writhing', 'protocal', 'mrcp', 'ecmo', 'spinous', 'thump', 'tranfer', 'colloid', 'vvs', 'breasts', 'hydrocephalus', 'abodmen', 'dextrose', 'drsgs', 'dates', 'myasthenia', 'bolemia', 'tremuolous', 'throat', 'slng', 'testicular', 'cirrohsis', 'span', 'om', 'undertreated', 'discontinue', 'benadryl', 'needed', 'terms', 'ined', 'angiographic', 'lyme', 'hepc', 'meconium', 'rheumatoid', 'keratitis', 'opthamologist', 'eruption', 'virl', 'stents', 'three', 'hiatal', 'patter', 'nrbm', 'papyracea', 'samonella', 'clindymacin', 'disorder', 'harvest', 'igm', 'improved', 'morni', 'interventions', 'reprots', 'schistocytes', 'city', 'paraplegic', 'mandibulectomy', 'transphenodial', 'multiform', 'succus', 'inr', 'sinuses', 'zofram', 'remaind', 'dysarthric', 'diminish', 'musk', 'podus', 'jumps', 'posture', 'phosphenytoin', 'lainectomy', 'subtherapeutic', 'extremeties', 'upright', 'step', 'epigastrum', 'oopherectomy', 'rifampin', 'unusal', 'burden', 'uncrossmatched', 'oscal', 'leucovorin', 'norvasc', 'teens', 'hyperkalemia', 'ddavp', 'reaching', 'gtts', 'incidentially', 'ripped', 'azithro', 'weaknes', 'cephalosporin', 'heria', 'ptt', 'answering', 'pnumothroax', 'eptifibatide', 'esr', 'less', 'alarming', 'app', 'ascitic', 'exhaustion', 'holes', 'cardiopulmonary', 'thrashes', 'tacchycardia', 'handfull', 'metasteses', 'falx', 'reintroduce', 'firm', 'backs', 'instrumentated', 'patterns', 'features', 'cables', 'grabbing', 'syn', 'adamantly', 'spots', 'tarry', 'presente', 'historians', 'contacks', 'colchicine', 'crystilloids', 'head', 'fragile', 'evolved', 'ctsurg', 'cephalosporins', 'clinical', 'compained', 'visual', 'desaturations', 'followup', 'booklet', 'lifted', 'life', 'borderline', 'db', 'proning', 'longacting', 'resusication', 'posible', 'airbag', 'lump', 'pvr', 'coming', 'tonsils', 'grimaces', 'bidnh', 'smiling', 'wearing', 'southern', 'nauseaus', 'palnning', 'cholilithiasis', 'demented', 'pruritus', 'ccy', 'excersion', 'anesthsia', 'identified', 'gangrene', 'parasentesis', 'breakdown', 'twin', 'guaze', 'diference', 'stigmata', 'implemented', 'dm', 'brbpr', 'kidney', 'lbp', 'cordus', 'aneurism', 'ruptrue', 'parapelegia', 'spokes', 'furthur', 'hypersensitive', 'bloodied', 'decbes', 'initialy', 'plate', 'percardial', 'blurred', 'jailed', 'parafalcine', 'unlabored', 'pylonephritis', 'rigidity', 'deferral', 'hand', 'transferred', 'idarubicin', 'trop', 'progression', 'icps', 'ringers', 'gallon', 'radiculopathy', 'cna', 'fround', 'poq', 'injur', 'gonorrhea', 'dl', 'vigelo', 'swearing', 'linens', 'shaking', 'tranverse', 'spectrum', 'sbos', 'causes', 'area', 'saturated', 'table', 'phys', 'emale', 'njo', 'original', 'desynchronous', 'ious', 'questionable', 'supportive', 'wtith', 'decadron', 'habitus', 'zysin', 'paradox', 'gallbladder', 'steroid', 'pneumothoraces', 'antibiodics', 'ndka', 'collide', 'circles', 'hte', 'mnt', 'diuresed', 'paperwork', 'grown', 'blisters', 'toliet', 'needsto', 'penetrated', 'glucosamine', 'pacemeaker', 'flipped', 'vincristine', 'run', 'lithotripsy', 'wegners', 'time', 'tng', 'hypernatremic', 'oseltamiver', 'doxil', 'ofr', 'gym', 'depth', 'productively', 'cleansing', 'retractions', 'fomepizole', 'case', 'distracted', 'thursdays', 'prod', 'widened', 'generalized', 'anxious', 'xc', 'cardizem', 'soup', 'attentive', 'clarification', 'coherently', 'pn', 'pleth', 'nitric', 'amnestic', 'situation', 'shower', 'pneumonia', 'foul', 'root', 'damped', 'adjunctive', 'maintainted', 'profiline', 'patella', 'hemachromatosis', 'cck', 'hallucinating', 'autopilot', 'future', 'cleaned', 'extended', 'tracking', 'street', 'cloth', 'liquefied', 'theeth', 'sternum', 'ileoconduit', 'exacerbated', 'hypokinetic', 'diuril', 'propranolol', 'cart', 'medicated', 'cistracurium', 'desatted', 'scabs', 'slao', 'sales', 'consumes', 'scarring', 'marks', 'spells', 'hemo', 'institution', 'floors', 'arrivaed', 'bifrontal', 'unbroken', 'logroll', 'decelerations', 'subsequent', ...

# %%
X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_train],dtype=object)
X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_test],dtype=object)

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
X_train_vect_avg = []
for v in X_train_vect:
    
    if v.size:
        X_train_vect_avg.append(v.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(300, dtype=float))
        
X_test_vect_avg = []
for v in X_test_vect:
    if v.size:
        X_test_vect_avg.append(v.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(300, dtype=float))

# %%
# Are our sentence vector lengths consistent?
for i, v in enumerate(X_train_vect_avg):
    print(len(X_train.iloc[i]), len(v))
# Out:
# 319 300
# 325 300
# 95 300
# 64 300
# 122 300
# 289 300
# 131 300
# 134 300
# 163 300
# 49 300
# 251 300
# 243 300
# 162 300
# 66 300
# 137 300
# 356 300
# 87 300
# 278 300
# 270 300
# 257 300
# 169 300
# 104 300
# 103 300
# 193 300
# 500 300
# 11 300
# 150 300
# 261 300
# 127 300
# 342 300
# 287 300
# 240 300
# 282 300
# 402 300
# 72 300
# 180 300
# 225 300
# 85 300
# 118 300
# 160 300
# 254 300
# 238 300
# 416 300
# 215 300
# 221 300
# 1 300
# 63 300
# 293 300
# 154 300
# 82 300
# 147 300
# 395 300
# 235 300
# 499 300
# 133 300
# 158 300
# 175 300
# 18 300
# 202 300
# 150 300
# 368 300
# 639 300
# 153 300
# 344 300
# 46 300
# 165 300
# 54 300
# 320 300
# 238 300
# 252 300
# 107 300
# 125 300
# 178 300
# 462 300
# 160 300
# 496 300
# 139 300
# 174 300
# 130 300
# 40 300
# 278 300
# 9 300
# 147 300
# 8 300
# 82 300
# 233 300
# 284 300
# 382 300
# 295 300
# 127 300
# 35 300
# 197 300
# 27 300
# 179 300
# 250 300
# 269 300
# 280 300
# 278 300
# 132 300
# 79 300
# 502 300
# 152 300
# 147 300
# 14 300
# 348 300
# 79 300
# 435 300
# 387 300
# 173 300
# 116 300
# 295 300
# 124 300
# 151 300
# 71 300
# 38 300
# 239 300
# 358 300
# 390 300
# 157 300
# 156 300
# 253 300
# 212 300
# 196 300
# 164 300
# 261 300
# 229 300
# 267 300
# 309 300
# 153 300
# 60 300
# 103 300
# 308 300
# 283 300
# 118 300
# 30 300
# 139 300
# 170 300
# 136 300
# 114 300
# 16 300
# 72 300
# 6 300
# 200 300
# 227 300
# 215 300
# 651 300
# 101 300
# 30 300
# 232 300
# 130 300
# 36 300
# 114 300
# 44 300
# 312 300
# 165 300
# 258 300
# 36 300
# 167 300
# 39 300
# 149 300
# 402 300
# 278 300
# 400 300
# 161 300
# 67 300
# 87 300
# 220 300
# 294 300
# 186 300
# 379 300
# 112 300
# 370 300
# 292 300
# 18 300
# 152 300
# 266 300
# 264 300
# 247 300
# 73 300
# 223 300
# 256 300
# 361 300
# 481 300
# 298 300
# 261 300
# 222 300
# 263 300
# 253 300
# 134 300
# 137 300
# 189 300
# 66 300
# 45 300
# 255 300
# 150 300
# 106 300
# 255 300
# 149 300
# 97 300
# 506 300
# 115 300
# 22 300
# 110 300
# 412 300
# 102 300
# 399 300
# 120 300
# 101 300
# 436 300
# 156 300
# 363 300
# 34 300
# 288 300
# 204 300
# 311 300
# 336 300
# 293 300
# 77 300
# 250 300
# 198 300
# 149 300
# 247 300
# 189 300
# 269 300
# 343 300
# 194 300
# 147 300
# 191 300
# 160 300
# 77 300
# 150 300
# 163 300
# 592 300
# 293 300
# 5 300
# 67 300
# 187 300
# 205 300
# 96 300
# 72 300
# 233 300
# 474 300
# 205 300
# 428 300
# 354 300
# 542 300
# 89 300
# 116 300
# 347 300
# 116 300
# 107 300
# 92 300
# 430 300
# 140 300
# 205 300
# 311 300
# 79 300
# 136 300
# 238 300
# 237 300
# 155 300
# 37 300
# 262 300
# 205 300
# 81 300
# 132 300
# 489 300
# 285 300
# 154 300
# 310 300
# 120 300
# 604 300
# 227 300
# 167 300
# 280 300
# 113 300
# 272 300
# 12 300
# 375 300
# 16 300
# 241 300
# 228 300
# 259 300
# 221 300
# 11 300
# 202 300
# 111 300
# 238 300
# 137 300
# 344 300
# 432 300
# 228 300
# 27 300
# 349 300
# 471 300
# 117 300
# 249 300
# 41 300
# 110 300
# 101 300
# 113 300
# 22 300
# 381 300
# 210 300
# 85 300
# 10 300
# 246 300
# 282 300
# 231 300
# 252 300
# 157 300
# 193 300
# 294 300
# 146 300
# 675 300
# 370 300
# 148 300
# 59 300
# 90 300
# 360 300
# 353 300
# 251 300
# 447 300
# 19 300
# 273 300
# 224 300
# 222 300
# 162 300
# 80 300
# 143 300
# 66 300
# 473 300
# 449 300
# 240 300
# 501 300
# 183 300
# 256 300
# 176 300
# 51 300
# 180 300
# 200 300
# 9 300
# 440 300
# 308 300
# 237 300
# 275 300
# 317 300
# 271 300
# 120 300
# 146 300
# 139 300
# 575 300
# 85 300
# 449 300
# 254 300
# 196 300
# 308 300
# 118 300
# 217 300
# 116 300
# 127 300
# 415 300
# 212 300
# 321 300
# 395 300
# 212 300
# 275 300
# 128 300
# 128 300
# 87 300
# 244 300
# 206 300
# 323 300
# 203 300
# 122 300
# 375 300
# 355 300
# 152 300
# 163 300
# 175 300
# 137 300
# 279 300
# 199 300
# 509 300
# 580 300
# 145 300
# 269 300
# 362 300
# 173 300
# 19 300
# 77 300
# 253 300
# 227 300
# 183 300
# 213 300
# 394 300
# 287 300
# 128 300
# 461 300
# 86 300
# 212 300
# 25 300
# 192 300
# 197 300
# 109 300
# 166 300
# 144 300
# 109 300
# 280 300
# 335 300
# 228 300
# 25 300
# 500 300
# 342 300
# 94 300
# 173 300
# 89 300
# 156 300
# 214 300
# 511 300
# 94 300
# 129 300
# 367 300
# 77 300
# 306 300
# 106 300
# 410 300
# 313 300
# 193 300
# 118 300
# 310 300
# 368 300
# 528 300
# 324 300
# 217 300
# 157 300
# 305 300
# 109 300
# 161 300
# 331 300
# 122 300
# 184 300
# 365 300
# 94 300
# 74 300
# 118 300
# 87 300
# 144 300
# 316 300
# 308 300
# 319 300
# 101 300
# 352 300
# 65 300
# 406 300
# 96 300
# 84 300
# 411 300
# 404 300
# 219 300
# 502 300
# 233 300
# 190 300
# 160 300
# 124 300
# 83 300
# 112 300
# 341 300
# 338 300
# 105 300
# 338 300
# 353 300
# 120 300
# 234 300
# 209 300
# 12 300
# 258 300
# 153 300
# 267 300
# 39 300
# 234 300
# 22 300
# 281 300
# 216 300
# 226 300
# 98 300
# 73 300
# 100 300
# 84 300
# 199 300
# 50 300
# 84 300
# 235 300
# 28 300
# 234 300
# 200 300
# 167 300
# 183 300
# 126 300
# 37 300
# 292 300
# 376 300
# 376 300
# 287 300
# 403 300
# 28 300
# 50 300
# 13 300
# 89 300
# 217 300
# 531 300
# 189 300
# 45 300
# 225 300
# 194 300
# 388 300
# 289 300
# 228 300
# 217 300
# 397 300
# 203 300
# 180 300
# 306 300
# 28 300
# 281 300
# 181 300
# 171 300
# 342 300
# 677 300
# 309 300
# 147 300
# 192 300
# 241 300
# 63 300
# 276 300
# 152 300
# 172 300
# 168 300
# 91 300
# 61 300
# 395 300
# 165 300
# 138 300
# 115 300
# 310 300
# 147 300
# 259 300
# 38 300
# 245 300
# 140 300
# 252 300
# 62 300
# 139 300
# 20 300
# 58 300
# 189 300
# 129 300
# 105 300
# 72 300
# 449 300
# 114 300
# 40 300
# 116 300
# 167 300
# 9 300
# 206 300
# 266 300
# 115 300
# 13 300
# 182 300
# 144 300
# 226 300
# 110 300
# 104 300
# 242 300
# 149 300
# 158 300
# 8 300
# 517 300
# 75 300
# 46 300
# 166 300
# 556 300
# 126 300
# 238 300
# 77 300
# 196 300
# 196 300
# 123 300
# 154 300
# 626 300
# 257 300
# 38 300
# 180 300
# 137 300
# 76 300
# 386 300
# 207 300
# 105 300
# 144 300
# 362 300
# 153 300
# 55 300
# 280 300
# 193 300
# 238 300
# 496 300
# 70 300
# 159 300
# 385 300
# 328 300
# 79 300
# 463 300
# 130 300
# 102 300
# 455 300
# 183 300
# 168 300
# 287 300
# 146 300
# 642 300
# 178 300
# 127 300
# 168 300
# 22 300
# 350 300
# 62 300
# 158 300
# 47 300
# 209 300
# 127 300
# 81 300
# 171 300
# 209 300
# 23 300
# 368 300
# 124 300
# 221 300
# 577 300
# 9 300
# 312 300
# 134 300
# 385 300
# 137 300
# 178 300
# 177 300
# 63 300
# 341 300
# 177 300
# 63 300
# 206 300
# 106 300
# 196 300
# 38 300
# 146 300
# 170 300
# 351 300
# 18 300
# 324 300
# 130 300
# 143 300
# 597 300
# 107 300
# 122 300
# 161 300
# 316 300
# 839 300
# 212 300
# 322 300
# 392 300
# 75 300
# 31 300
# 109 300
# 145 300
# 274 300
# 289 300
# 201 300
# 144 300
# 143 300
# 99 300
# 232 300
# 76 300
# 179 300
# 317 300
# 233 300
# 173 300
# 136 300
# 417 300
# 15 300
# 10 300
# 146 300
# 76 300
# 39 300
# 164 300
# 232 300
# 253 300
# 163 300
# 24 300
# 356 300
# 119 300
# 335 300
# 53 300
# 286 300
# 162 300
# 105 300
# 92 300
# 166 300
# 187 300
# 399 300
# 154 300
# 109 300
# 146 300
# 205 300
# 6 300
# 178 300
# 52 300
# 125 300
# 1 300
# 230 300
# 431 300
# 239 300
# 161 300
# 135 300
# 21 300
# 344 300
# 92 300
# 315 300
# 125 300
# 117 300
# 317 300
# 164 300
# 349 300
# 138 300
# 60 300
# 174 300
# 12 300
# 378 300
# 130 300
# 119 300
# 218 300
# 318 300
# 262 300
# 618 300
# 409 300
# 210 300
# 79 300
# 361 300
# 85 300
# 759 300
# 235 300
# 12 300
# 68 300
# 223 300
# 34 300
# 206 300
# 159 300
# 171 300
# 75 300
# 134 300
# 476 300
# 422 300
# 340 300
# 330 300
# 44 300
# 336 300
# 347 300
# 137 300
# 119 300
# 207 300
# 195 300
# 234 300
# 179 300
# 191 300
# 182 300
# 311 300
# 270 300
# 455 300
# 89 300
# 166 300
# 100 300
# 225 300
# 121 300
# 123 300
# 226 300
# 497 300
# 166 300
# 353 300
# 162 300
# 189 300
# 79 300
# 84 300
# 104 300
# 163 300
# 205 300
# 163 300
# 186 300
# 184 300
# 386 300
# 152 300
# 304 300
# 181 300
# 150 300
# 64 300
# 269 300
# 288 300
# 322 300
# 145 300
# 318 300
# 453 300
# 344 300
# 163 300
# 759 300
# 329 300
# 391 300
# 467 300
# 244 300
# 229 300
# 197 300
# 129 300
# 177 300
# 120 300
# 69 300
# 123 300
# 121 300
# 265 300
# 208 300
# 149 300
# 13 300
# 75 300
# 234 300
# 31 300
# 144 300
# 215 300
# 242 300
# 383 300
# 569 300
# 87 300
# 1 300
# 184 300
# 206 300
# 233 300
# 218 300
# 196 300
# 154 300
# 310 300
# 203 300
# 257 300
# 239 300
# 221 300
# 203 300
# 223 300
# 229 300
# 405 300
# 265 300
# 358 300
# 137 300
# 378 300
# 292 300
# 174 300
# 290 300
# 167 300
# 39 300
# 221 300
# 105 300
# 79 300
# 134 300
# 397 300
# 399 300
# 216 300
# 75 300
# 113 300
# 215 300
# 125 300
# 46 300
# 142 300
# 244 300
# 198 300
# 65 300
# 119 300
# 658 300
# 140 300
# 121 300
# 126 300
# 241 300
# 232 300
# 165 300
# 134 300
# 255 300
# 156 300
# 181 300
# 11 300
# 395 300
# 283 300
# 166 300
# 499 300
# 191 300
# 39 300
# 224 300
# 337 300
# 213 300
# 215 300
# 407 300
# 62 300
# 231 300
# 221 300
# 187 300
# 359 300
# 467 300
# 123 300
# 314 300
# 264 300
# 135 300
# 141 300
# 113 300
# 336 300
# 180 300
# 245 300
# 65 300
# 440 300
# 94 300
# 115 300
# 112 300
# 115 300
# 154 300
# 217 300
# 235 300
# 199 300
# 416 300
# 327 300
# 156 300
# 223 300
# 220 300
# 291 300
# 105 300
# 168 300
# 153 300
# 295 300
# 131 300
# 118 300
# 127 300
# 229 300
# 66 300
# 169 300
# 376 300
# 211 300
# 173 300
# 351 300
# 382 300
# 216 300
# 147 300
# 381 300
# 128 300
# 412 300
# 225 300
# 261 300
# 104 300
# 177 300
# 172 300
# 143 300
# 139 300
# 131 300
# 116 300
# 63 300
# 141 300
# 384 300
# 519 300
# 237 300
# 83 300
# 499 300
# 112 300
# 113 300
# 315 300
# 151 300
# 56 300
# 40 300
# 186 300
# 294 300
# 391 300
# 462 300
# 381 300
# 96 300
# 83 300
# 12 300
# 277 300
# 349 300
# 153 300
# 398 300
# 159 300
# 154 300
# 108 300
# 259 300
# 69 300
# 97 300
# 210 300
# 202 300
# 193 300
# 304 300
# 185 300
# 155 300
# 137 300
# 216 300
# 97 300
# 229 300
# 127 300
# 105 300
# 353 300
# 249 300
# 235 300
# 125 300
# 245 300
# 196 300
# 106 300
# 134 300
# 134 300
# 384 300
# 198 300
# 297 300
# 351 300
# 161 300
# 427 300
# 180 300
# 82 300
# 124 300
# 183 300
# 133 300
# 204 300
# 186 300
# 152 300
# 156 300
# 243 300
# 280 300
# 160 300
# 307 300
# 173 300
# 219 300
# 217 300
# 116 300
# 219 300
# 120 300
# 301 300
# 138 300
# 193 300
# 172 300
# 266 300
# 22 300
# 30 300
# 272 300
# 335 300
# 76 300
# 6 300
# 342 300
# 19 300
# 442 300
# 67 300
# 146 300
# 224 300
# 125 300
# 171 300
# 155 300
# 371 300
# 303 300
# 397 300
# 153 300
# 126 300
# 192 300
# 5 300
# 250 300
# 299 300
# 133 300
# 115 300
# 335 300
# 206 300
# 147 300
# 303 300
# 9 300
# 223 300
# 164 300
# 121 300
# 7 300
# 245 300
# 198 300
# 415 300
# 74 300
# 313 300
# 524 300
# 59 300
# 118 300
# 232 300
# 235 300
# 229 300
# 89 300
# 65 300
# 203 300
# 158 300
# 279 300
# 307 300
# 70 300
# 245 300
# 363 300
# 183 300
# 120 300
# 134 300
# 172 300
# 163 300
# 352 300
# 90 300
# 391 300
# 639 300
# 621 300
# 129 300
# 406 300
# 352 300
# 252 300
# 200 300
# 345 300
# 203 300
# 442 300
# 269 300
# 485 300
# 146 300
# 481 300
# 245 300
# 384 300
# 135 300
# 669 300
# 143 300
# 23 300
# 565 300
# 487 300
# 228 300
# 380 300
# 369 300
# 14 300
# 22 300
# 154 300
# 191 300
# 157 300
# 304 300
# 58 300
# 185 300
# 259 300
# 246 300
# 19 300
# 182 300
# 84 300
# 35 300
# 34 300
# 430 300
# 156 300
# 334 300
# 226 300
# 98 300
# 85 300
# 158 300
# 14 300
# 175 300
# 142 300
# 214 300
# 127 300
# 34 300
# 201 300
# 17 300
# 201 300
# 200 300
# 257 300
# 106 300
# 139 300
# 145 300
# 66 300
# 54 300
# 376 300
# 245 300
# 290 300
# 270 300
# 253 300
# 410 300
# 52 300
# 200 300
# 229 300
# 448 300
# 49 300
# 101 300
# 346 300
# 375 300
# 194 300
# 339 300
# 203 300
# 66 300
# 169 300
# 298 300
# 55 300
# 268 300
# 422 300
# 89 300
# 241 300
# 274 300
# 189 300
# 24 300
# 431 300
# 10 300
# 66 300
# 474 300
# 101 300
# 219 300
# 224 300
# 195 300
# 12 300
# 249 300
# 257 300
# 215 300
# 319 300
# 309 300
# 106 300
# 262 300
# 310 300
# 245 300
# 10 300
# 210 300
# 292 300
# 280 300
# 128 300
# 237 300
# 672 300
# 103 300
# 496 300
# 243 300
# 408 300
# 126 300
# 426 300
# 11 300
# 656 300
# 332 300
# 81 300
# 107 300
# 287 300
# 40 300
# 56 300
# 366 300
# 189 300
# 332 300
# 251 300
# 114 300
# 303 300
# 314 300
# 237 300
# 70 300
# 127 300
# 185 300
# 23 300
# 187 300
# 134 300
# 138 300
# 219 300
# 364 300
# 278 300
# 360 300
# 246 300
# 298 300
# 5 300
# 151 300
# 207 300
# 263 300
# 8 300
# 110 300
# 131 300
# 121 300
# 513 300
# 27 300
# 192 300
# 198 300
# 324 300
# 258 300
# 136 300
# 126 300
# 178 300
# 361 300
# 237 300
# 405 300
# 172 300
# 385 300
# 28 300
# 117 300
# 158 300
# 217 300
# 498 300
# 198 300
# 272 300
# 146 300
# 413 300
# 157 300
# 307 300
# 50 300
# 35 300
# 114 300
# 397 300
# 260 300
# 374 300
# 163 300
# 141 300
# 119 300
# 400 300
# 167 300
# 111 300
# 584 300
# 181 300
# 153 300
# 66 300
# 433 300
# 243 300
# 189 300
# 338 300
# 101 300
# 154 300
# 253 300
# 330 300
# 47 300
# 191 300
# 196 300
# 301 300
# 184 300
# 252 300
# 84 300
# 197 300
# 111 300
# 119 300
# 95 300
# 181 300
# 100 300
# 251 300
# 94 300
# 164 300
# 221 300
# 259 300
# 233 300
# 211 300
# 150 300
# 96 300
# 242 300
# 185 300
# 16 300
# 161 300
# 131 300
# 70 300
# 140 300
# 561 300
# 250 300
# 310 300
# 253 300
# 323 300
# 112 300
# 75 300
# 345 300
# 434 300
# 434 300
# 480 300
# 61 300
# 229 300
# 154 300
# 330 300
# 211 300
# 61 300
# 167 300
# 346 300
# 82 300
# 221 300
# 188 300
# 163 300
# 228 300
# 344 300
# 176 300
# 104 300
# 150 300
# 86 300
# 89 300
# 99 300
# 71 300
# 227 300
# 99 300
# 152 300
# 228 300
# 309 300
# 480 300
# 88 300
# 204 300
# 75 300
# 193 300
# 47 300
# 126 300
# 229 300
# 45 300
# 127 300
# 98 300
# 207 300
# 139 300
# 98 300
# 78 300
# 205 300
# 222 300
# 290 300
# 68 300
# 29 300
# 337 300
# 247 300
# 60 300
# 306 300
# 77 300
# 112 300
# 409 300
# 261 300
# 272 300
# 243 300
# 340 300
# 439 300
# 317 300
# 15 300
# 240 300
# 76 300
# 315 300
# 298 300
# 11 300
# 165 300
# 231 300
# 83 300
# 354 300
# 263 300
# 37 300
# 407 300
# 329 300
# 92 300
# 274 300
# 168 300
# 79 300
# 129 300
# 213 300
# 53 300
# 15 300
# 39 300
# 338 300
# 118 300
# 21 300
# 203 300
# 306 300
# 337 300
# 292 300
# 112 300
# 275 300
# 319 300
# 256 300
# 288 300
# 122 300
# 126 300
# 291 300
# 11 300
# 185 300
# 358 300
# 314 300
# 56 300
# 215 300
# 262 300
# 215 300
# 96 300
# 86 300
# 457 300
# 193 300
# 114 300
# 23 300
# 273 300
# 189 300
# 79 300
# 42 300
# 163 300
# 298 300
# 257 300
# 52 300
# 203 300
# 211 300
# 262 300
# 260 300
# 353 300
# 119 300
# 144 300
# 30 300
# 228 300
# 292 300
# 153 300
# 234 300
# 94 300
# 99 300
# 91 300
# 267 300
# 173 300
# 61 300
# 290 300
# 186 300
# 205 300
# 462 300
# 94 300
# 188 300
# 81 300
# 259 300
# 82 300
# 155 300
# 155 300
# 235 300
# 213 300
# 131 300
# 185 300
# 353 300
# 131 300
# 235 300
# 8 300
# 53 300
# 139 300
# 13 300
# 276 300
# 206 300
# 167 300
# 206 300
# 345 300
# 149 300
# 215 300
# 311 300
# 145 300
# 9 300
# 253 300
# 186 300
# 131 300
# 267 300
# 150 300
# 295 300
# 621 300
# 131 300
# 364 300
# 98 300
# 231 300
# 220 300
# 54 300
# 106 300
# 314 300
# 81 300
# 147 300
# 98 300
# 168 300
# 112 300
# 133 300
# 209 300
# 48 300
# 11 300
# 3 300
# 108 300
# 213 300
# 739 300
# 98 300
# 234 300
# 67 300
# 160 300
# 181 300
# 182 300
# 17 300
# 145 300
# 249 300
# 549 300
# 109 300
# 391 300
# 358 300
# 580 300
# 123 300
# 267 300
# 354 300
# 353 300
# 295 300
# 312 300
# 107 300
# 111 300
# 463 300
# 393 300
# 37 300
# 152 300
# 115 300
# 62 300
# 127 300
# 94 300
# 177 300
# 67 300
# 488 300
# 313 300
# 200 300
# 230 300
# 67 300
# 202 300
# 75 300
# 54 300
# 216 300
# 251 300
# 184 300
# 422 300
# 92 300
# 173 300
# 396 300
# 321 300
# 211 300
# 386 300
# 374 300
# 123 300
# 215 300
# 67 300
# 215 300
# 223 300
# 208 300
# 150 300
# 215 300
# 455 300
# 385 300
# 224 300
# 325 300
# 111 300
# 207 300
# 182 300
# 438 300
# 261 300
# 82 300
# 73 300
# 70 300
# 271 300
# 393 300
# 19 300
# 162 300
# 83 300
# 508 300
# 393 300
# 207 300
# 73 300
# 244 300
# 473 300
# 367 300
# 72 300
# 209 300
# 183 300
# 210 300
# 143 300
# 149 300
# 82 300
# 197 300
# 254 300
# 333 300
# 164 300
# 217 300
# 158 300
# 443 300
# 68 300
# 105 300
# 110 300
# 103 300
# 83 300
# 345 300
# 161 300
# 7 300
# 131 300
# 14 300
# 27 300
# 213 300
# 207 300
# 166 300
# 333 300
# 67 300
# 177 300
# 7 300
# 188 300
# 287 300
# 161 300
# 266 300
# 536 300
# 305 300
# 89 300
# 171 300
# 182 300
# 83 300
# 170 300
# 205 300
# 94 300
# 182 300
# 106 300
# 286 300
# 20 300
# 191 300
# 157 300
# 199 300
# 227 300
# 158 300
# 279 300
# 241 300
# 139 300
# 132 300
# 298 300
# 194 300
# 93 300
# 105 300
# 101 300
# 122 300
# 19 300
# 283 300
# 198 300
# 7 300
# 510 300
# 214 300
# 114 300
# 28 300
# 19 300
# 372 300
# 397 300
# 362 300
# 219 300
# 308 300
# 264 300
# 183 300
# 440 300
# 53 300
# 98 300
# 164 300
# 75 300
# 347 300
# 182 300
# 341 300
# 301 300
# 234 300
# 135 300
# 78 300
# 188 300
# 85 300
# 12 300
# 321 300
# 277 300
# 1403 300
# 142 300
# 162 300
# 326 300
# 95 300
# 35 300
# 114 300
# 268 300
# 150 300
# 205 300
# 229 300
# 193 300
# 132 300
# 90 300
# 86 300
# 320 300
# 54 300
# 152 300
# 262 300
# 150 300
# 186 300
# 86 300
# 274 300
# 105 300
# 113 300
# 102 300
# 370 300
# 107 300
# 183 300
# 387 300
# 159 300
# 296 300
# 261 300
# 123 300
# 140 300
# 210 300
# 477 300
# 119 300
# 272 300
# 304 300
# 65 300
# 294 300
# 151 300
# 279 300
# 166 300
# 125 300
# 130 300
# 137 300
# 203 300
# 412 300
# 422 300
# 71 300
# 174 300
# 277 300
# 17 300
# 299 300
# 245 300
# 134 300
# 22 300
# 282 300
# 52 300
# 105 300
# 180 300
# 73 300
# 347 300
# 26 300
# 444 300
# 110 300
# 59 300
# 317 300
# 107 300
# 274 300
# 328 300
# 171 300
# 78 300
# 119 300
# 193 300
# 297 300
# 381 300
# 32 300
# 221 300
# 186 300
# 168 300
# 290 300
# 123 300
# 165 300
# 332 300
# 177 300
# 146 300
# 450 300
# 199 300
# 169 300
# 270 300
# 316 300
# 249 300
# 391 300
# 118 300
# 84 300
# 57 300
# 443 300
# 31 300
# 19 300
# 342 300
# 165 300
# 194 300
# 264 300
# 173 300
# 320 300
# 261 300
# 174 300
# 257 300
# 319 300
# 98 300
# 437 300
# 172 300
# 349 300
# 104 300
# 181 300
# 247 300
# 101 300
# 165 300
# 381 300
# 520 300
# 159 300
# 81 300
# 428 300
# 290 300
# 207 300
# 470 300
# 158 300
# 136 300
# 12 300
# 260 300
# 193 300
# 79 300
# 241 300
# 298 300
# 266 300
# 325 300
# 274 300
# 139 300
# 165 300
# 311 300
# 182 300
# 99 300
# 271 300
# 243 300
# 19 300
# 144 300
# 276 300
# 408 300
# 466 300
# 144 300
# 269 300
# 164 300
# 229 300
# 111 300
# 204 300
# 83 300
# 27 300
# 57 300
# 342 300
# 14 300
# 275 300
# 541 300
# 136 300
# 70 300
# 195 300
# 289 300
# 121 300
# 248 300
# 320 300
# 285 300
# 168 300
# 287 300
# 341 300
# 207 300
# 136 300
# 34 300
# 216 300
# 169 300
# 154 300
# 150 300
# 44 300
# 170 300
# 215 300
# 197 300
# 233 300
# 395 300
# 295 300
# 137 300
# 301 300
# 293 300
# 226 300
# 247 300
# 76 300
# 98 300
# 442 300
# 109 300
# 400 300
# 88 300
# 184 300
# 197 300
# 435 300
# 339 300
# 291 300
# 652 300
# 39 300
# 569 300
# 417 300
# 78 300
# 301 300
# 139 300
# 427 300
# 155 300
# 265 300
# 94 300
# 372 300
# 99 300
# 264 300
# 216 300
# 516 300
# 25 300
# 131 300
# 97 300
# 255 300
# 245 300
# 247 300
# 204 300
# 269 300
# 227 300
# 102 300
# 64 300
# 140 300
# 296 300
# 207 300
# 286 300
# 142 300
# 132 300
# 123 300
# 6 300
# 387 300
# 170 300
# 134 300
# 110 300
# 533 300
# 327 300
# 343 300
# 158 300
# 367 300
# 333 300
# 328 300
# 9 300
# 389 300
# 20 300
# 375 300
# 44 300
# 525 300
# 123 300
# 192 300
# 325 300
# 126 300
# 150 300
# 107 300
# 180 300
# 236 300
# 193 300
# 132 300
# 341 300
# 202 300
# 274 300
# 116 300
# 124 300
# 153 300
# 125 300
# 235 300
# 407 300
# 342 300
# 493 300
# 171 300
# 188 300
# 405 300
# 156 300
# 340 300
# 479 300
# 281 300
# 82 300
# 230 300
# 575 300
# 205 300
# 122 300
# 358 300
# 24 300
# 175 300
# 200 300
# 307 300
# 131 300
# 212 300
# 370 300
# 366 300
# 267 300
# 5 300
# 128 300
# 205 300
# 129 300
# 213 300
# 162 300
# 50 300
# 240 300
# 227 300
# 347 300
# 153 300
# 137 300
# 175 300
# 236 300
# 209 300
# 553 300
# 129 300
# 145 300
# 305 300
# 142 300
# 259 300
# 133 300
# 86 300
# 72 300
# 85 300
# 79 300
# 210 300
# 156 300
# 98 300
# 276 300
# 231 300
# 108 300
# 234 300
# 83 300
# 295 300
# 275 300
# 135 300
# 182 300
# 9 300
# 148 300
# 552 300
# 158 300
# 382 300
# 217 300
# 285 300
# 337 300
# 166 300
# 69 300
# 393 300
# 141 300
# 310 300
# 162 300
# 289 300
# 337 300
# 276 300
# 35 300
# 250 300
# 154 300
# 206 300
# 182 300
# 92 300
# 546 300
# 171 300
# 92 300
# 145 300
# 106 300
# 159 300
# 109 300
# 119 300
# 19 300
# 315 300
# 245 300
# 200 300
# 144 300
# 166 300
# 344 300
# 190 300
# 107 300
# 319 300
# 170 300
# 169 300
# 373 300
# 203 300
# 240 300
# 103 300
# 151 300
# 25 300
# 43 300
# 209 300
# 456 300
# 167 300
# 196 300
# 87 300
# 68 300
# 295 300
# 221 300
# 136 300
# 238 300
# 223 300
# 454 300
# 225 300
# 129 300
# 91 300
# 286 300
# 313 300
# 181 300
# 199 300
# 203 300
# 321 300
# 106 300
# 164 300
# 356 300
# 120 300
# 192 300
# 174 300
# 274 300
# 276 300
# 270 300
# 515 300
# 289 300
# 198 300
# 24 300
# 87 300
# 102 300
# 172 300
# 388 300
# 102 300
# 238 300
# 77 300
# 427 300
# 73 300
# 225 300
# 128 300
# 192 300
# 131 300
# 287 300
# 7 300
# 169 300
# 242 300
# 472 300
# 98 300
# 432 300
# 154 300
# 191 300
# 201 300
# 381 300
# 113 300
# 138 300
# 239 300
# 96 300
# 126 300
# 85 300
# 45 300
# 269 300
# 317 300
# 58 300
# 20 300
# 43 300
# 289 300
# 183 300
# 146 300
# 95 300
# 142 300
# 24 300
# 187 300
# 95 300
# 207 300
# 411 300
# 17 300
# 51 300
# 217 300
# 85 300
# 300 300
# 342 300
# 192 300
# 267 300
# 208 300
# 347 300
# 124 300
# 355 300
# 406 300
# 139 300
# 165 300
# 111 300
# 48 300
# 243 300
# 50 300
# 232 300
# 206 300
# 248 300
# 114 300
# 207 300
# 231 300
# 433 300
# 145 300
# 225 300
# 27 300
# 186 300
# 8 300
# 182 300
# 212 300
# 371 300
# 172 300
# 235 300
# 401 300
# 71 300
# 368 300
# 291 300
# 263 300
# 348 300
# 181 300
# 57 300
# 121 300
# 280 300
# 93 300
# 93 300
# 406 300
# 150 300
# 127 300
# 32 300
# 92 300
# 2 300
# 173 300
# 241 300
# 389 300
# 260 300
# 317 300
# 129 300
# 107 300
# 211 300
# 109 300
# 102 300
# 249 300
# 290 300
# 168 300
# 320 300
# 239 300
# 244 300
# 18 300
# 170 300
# 216 300
# 111 300
# 430 300
# 206 300
# 281 300
# 81 300
# 141 300
# 384 300
# 293 300
# 419 300
# 48 300
# 306 300
# 125 300
# 49 300
# 98 300
# 101 300
# 79 300
# 334 300
# 155 300
# 314 300
# 46 300
# 151 300
# 429 300
# 468 300
# 198 300
# 64 300
# 149 300
# 95 300
# 165 300
# 137 300
# 15 300
# 176 300
# 265 300
# 105 300
# 295 300
# 149 300
# 156 300
# 23 300
# 99 300
# 19 300
# 7 300
# 338 300
# 876 300
# 329 300
# 90 300
# 186 300
# 236 300
# 373 300
# 307 300
# 18 300
# 96 300
# 259 300
# 528 300
# 196 300
# 121 300
# 187 300
# 449 300
# 84 300
# 101 300
# 292 300
# 154 300
# 92 300
# 148 300
# 135 300
# 218 300
# 395 300
# 255 300
# 323 300
# 331 300
# 218 300
# 255 300
# 356 300
# 426 300
# 394 300
# 107 300
# 655 300
# 294 300
# 314 300
# 351 300
# 442 300
# 116 300
# 414 300
# 24 300
# 205 300
# 169 300
# 12 300
# 64 300
# 259 300
# 189 300
# 267 300
# 7 300
# 45 300
# 115 300
# 64 300
# 18 300
# 225 300
# 60 300
# 150 300
# 231 300
# 286 300
# 246 300
# 182 300
# 336 300
# 126 300
# 315 300
# 256 300
# 544 300
# 27 300
# 355 300
# 197 300
# 414 300
# 231 300
# 92 300
# 92 300
# 227 300
# 170 300
# 219 300
# 164 300
# 161 300
# 188 300
# 16 300
# 238 300
# 118 300
# 198 300
# 268 300
# 156 300
# 441 300
# 159 300
# 132 300
# 306 300
# 556 300
# 281 300
# 147 300
# 161 300
# 189 300
# 44 300
# 110 300
# 267 300
# 202 300
# 134 300
# 232 300
# 406 300
# 317 300
# 189 300
# 183 300
# 236 300
# 71 300
# 234 300
# 180 300
# 93 300
# 123 300
# 204 300
# 185 300
# 213 300
# 324 300
# 16 300
# 72 300
# 117 300
# 88 300
# 218 300
# 38 300
# 374 300
# 268 300
# 326 300
# 487 300
# 262 300
# 74 300
# 107 300
# 11 300
# 223 300
# 238 300
# 168 300
# 301 300
# 42 300
# 142 300
# 35 300
# 204 300
# 336 300
# 303 300
# 326 300
# 442 300
# 203 300
# 127 300
# 235 300
# 155 300
# 270 300
# 190 300
# 374 300
# 162 300
# 198 300
# 414 300
# 416 300
# 112 300
# 582 300
# 163 300
# 70 300
# 149 300
# 377 300
# 136 300
# 447 300
# 129 300
# 195 300
# 191 300
# 208 300
# 443 300
# 144 300
# 207 300
# 245 300
# 132 300
# 224 300
# 85 300
# 158 300
# 86 300
# 93 300
# 79 300
# 161 300
# 424 300
# 169 300
# 153 300
# 398 300
# 92 300
# 62 300
# 203 300
# 227 300
# 117 300
# 178 300
# 167 300
# 280 300
# 275 300
# 98 300
# 14 300
# 175 300
# 449 300
# 161 300
# 407 300
# 191 300
# 98 300
# 544 300
# 208 300
# 685 300
# 92 300
# 71 300
# 160 300
# 254 300
# 86 300
# 22 300
# 122 300
# 326 300
# 124 300
# 119 300
# 103 300
# 498 300
# 300 300
# 618 300
# 249 300
# 370 300
# 23 300
# 173 300
# 140 300
# 288 300
# 84 300
# 7 300
# 225 300
# 72 300
# 71 300
# 128 300
# 32 300
# 178 300
# 204 300
# 482 300
# 223 300
# 65 300
# 430 300
# 190 300
# 129 300
# 123 300
# 188 300
# 58 300
# 141 300
# 163 300
# 280 300
# 122 300
# 126 300
# 277 300
# 130 300
# 345 300
# 69 300
# 35 300
# 89 300
# 175 300
# 270 300
# 206 300
# 299 300
# 161 300
# 526 300
# 290 300
# 209 300
# 399 300
# 119 300
# 91 300
# 168 300
# 159 300
# 171 300
# 150 300
# 202 300
# 386 300
# 228 300
# 320 300
# 91 300
# 6 300
# 219 300
# 188 300
# 140 300
# 115 300
# 290 300
# 293 300
# 236 300
# 289 300
# 258 300
# 71 300
# 7 300
# 249 300
# 206 300
# 231 300
# 578 300
# 6 300
# 208 300
# 381 300
# 90 300
# 149 300
# 226 300
# 351 300
# 161 300
# 2 300
# 141 300
# 183 300
# 94 300
# 193 300
# 237 300
# 124 300
# 383 300
# 387 300
# 105 300
# 241 300
# 368 300
# 225 300
# 227 300
# 285 300
# 147 300
# 76 300
# 21 300
# 343 300
# 227 300
# 157 300
# 373 300
# 409 300
# 99 300
# 245 300
# 432 300
# 111 300
# 26 300
# 364 300
# 115 300
# 62 300
# 564 300
# 131 300
# 172 300
# 7 300
# 117 300
# 177 300
# 120 300
# 306 300
# 427 300
# 88 300
# 284 300
# 123 300
# 145 300
# 508 300
# 96 300
# 26 300
# 305 300
# 221 300
# 50 300
# 225 300
# 273 300
# 373 300
# 384 300
# 341 300
# 62 300
# 188 300
# 243 300
# 255 300
# 13 300
# 515 300
# 170 300
# 385 300
# 220 300
# 234 300
# 708 300
# 106 300
# 59 300
# 134 300
# 114 300
# 369 300
# 278 300
# 371 300
# 18 300
# 35 300
# 183 300
# 76 300
# 410 300
# 95 300
# 201 300
# 165 300
# 194 300
# 324 300
# 356 300
# 59 300
# 121 300
# 128 300
# 296 300
# 53 300
# 196 300
# 386 300
# 236 300
# 9 300
# 367 300
# 18 300
# 125 300
# 204 300
# 267 300
# 87 300
# 212 300
# 264 300
# 152 300
# 77 300
# 150 300
# 92 300
# 288 300
# 234 300
# 219 300
# 12 300
# 9 300
# 371 300
# 239 300
# 620 300
# 413 300
# 179 300
# 275 300
# 478 300
# 392 300
# 295 300
# 131 300
# 9 300
# 68 300
# 280 300
# 70 300
# 279 300
# 194 300
# 233 300
# 82 300
# 31 300
# 278 300
# 262 300
# 330 300
# 351 300
# 108 300
# 133 300
# 132 300
# 133 300
# 178 300
# 95 300
# 78 300
# 206 300
# 405 300
# 241 300
# 169 300
# 40 300
# 202 300
# 207 300
# 26 300
# 244 300
# 325 300
# 217 300
# 207 300
# 378 300
# 143 300
# 24 300
# 172 300
# 507 300
# 218 300
# 281 300
# 295 300
# 202 300
# 10 300
# 263 300
# 127 300
# 316 300
# 258 300
# 404 300
# 312 300
# 117 300
# 256 300
# 242 300
# 242 300
# 186 300
# 182 300
# 189 300
# 319 300
# 106 300
# 481 300
# 493 300
# 90 300
# 187 300
# 151 300
# 41 300
# 101 300
# 243 300
# 65 300
# 375 300
# 480 300
# 225 300
# 89 300
# 320 300
# 30 300
# 204 300
# 138 300
# 237 300
# 418 300
# 125 300
# 41 300
# 222 300
# 148 300
# 267 300
# 281 300
# 387 300
# 57 300
# 259 300
# 115 300
# 119 300
# 181 300
# 95 300
# 77 300
# 195 300
# 247 300
# 221 300
# 163 300
# 23 300
# 305 300
# 149 300
# 141 300
# 162 300
# 186 300
# 538 300
# 186 300
# 97 300
# 480 300
# 280 300
# 152 300
# 173 300
# 144 300
# 372 300
# 5 300
# 129 300
# 249 300
# 308 300
# 347 300
# 45 300
# 117 300
# 274 300
# 186 300
# 250 300
# 147 300
# 617 300
# 51 300
# 104 300
# 190 300
# 262 300
# 34 300
# 150 300
# 83 300
# 194 300
# 63 300
# 17 300
# 147 300
# 380 300
# 78 300
# 127 300
# 41 300
# 253 300
# 375 300
# 276 300
# 233 300
# 107 300
# 285 300
# 244 300
# 126 300
# 234 300
# 164 300
# 67 300
# 22 300
# 79 300
# 246 300
# 116 300
# 338 300
# 141 300
# 104 300
# 21 300
# 190 300
# 259 300
# 168 300
# 356 300
# 182 300
# 81 300
# 181 300
# 110 300
# 562 300
# 295 300
# 187 300
# 77 300
# 69 300
# 191 300
# 510 300
# 179 300
# 420 300
# 82 300
# 314 300
# 177 300
# 72 300
# 340 300
# 245 300
# 162 300
# 226 300
# 217 300
# 194 300
# 177 300
# 147 300
# 298 300
# 83 300
# 244 300
# 195 300
# 80 300
# 10 300
# 179 300
# 157 300
# 196 300
# 285 300
# 325 300
# 369 300
# 236 300
# 432 300
# 259 300
# 156 300
# 60 300
# 156 300
# 281 300
# 258 300
# 108 300
# 197 300
# 505 300
# 84 300
# 195 300
# 243 300
# 33 300
# 7 300
# 161 300
# 241 300
# 245 300
# 116 300
# 66 300
# 116 300
# 190 300
# 156 300
# 241 300
# 116 300
# 202 300
# 312 300
# 153 300
# 332 300
# 101 300
# 142 300
# 215 300
# 123 300
# 131 300
# 324 300
# 338 300
# 299 300
# 307 300
# 34 300
# 262 300
# 175 300
# 403 300
# 297 300
# 288 300
# 356 300
# 131 300
# 229 300
# 136 300
# 63 300
# 313 300
# 155 300
# 169 300
# 310 300
# 244 300
# 224 300
# 276 300
# 133 300
# 155 300
# 222 300
# 15 300
# 641 300
# 260 300
# 85 300
# 322 300
# 75 300
# 73 300
# 362 300
# 220 300
# 196 300
# 429 300
# 22 300
# 147 300
# 173 300
# 278 300
# 190 300
# 269 300
# 228 300
# 412 300
# 192 300
# 217 300
# 180 300
# 101 300
# 276 300
# 127 300
# 109 300
# 263 300
# 189 300
# 149 300
# 111 300
# 260 300
# 130 300
# 879 300
# 35 300
# 226 300
# 213 300
# 598 300
# 282 300
# 160 300
# 166 300
# 13 300
# 190 300
# 62 300
# 279 300
# 278 300
# 145 300
# 249 300
# 162 300
# 103 300
# 164 300
# 139 300
# 405 300
# 203 300
# 157 300
# 267 300
# 80 300
# 82 300
# 76 300
# 400 300
# 387 300
# 547 300
# 5 300
# 215 300
# 72 300
# 105 300
# 292 300
# 170 300
# 221 300
# 7 300
# 251 300
# 94 300
# 187 300
# 97 300
# 140 300
# 180 300
# 327 300
# 284 300
# 305 300
# 110 300
# 239 300
# 141 300
# 121 300
# 265 300
# 237 300
# 233 300
# 269 300
# 180 300
# 70 300
# 120 300
# 244 300
# 373 300
# 200 300
# 2 300
# 340 300
# 523 300
# 376 300
# 160 300
# 689 300
# 490 300
# 165 300
# 229 300
# 423 300
# 246 300
# 172 300
# 248 300
# 174 300
# 191 300
# 294 300
# 155 300
# 8 300
# 302 300
# 336 300
# 129 300
# 119 300
# 178 300
# 185 300
# 322 300
# 130 300
# 215 300
# 228 300
# 323 300
# 227 300
# 261 300
# 170 300
# 184 300
# 169 300
# 185 300
# 263 300
# 300 300
# 131 300
# 419 300
# 156 300
# 150 300
# 120 300
# 167 300
# 163 300
# 133 300
# 129 300
# 665 300
# 236 300
# 165 300
# 80 300
# 303 300
# 650 300
# 122 300
# 181 300
# 521 300
# 449 300
# 228 300
# 105 300
# 337 300
# 245 300
# 363 300
# 210 300
# 293 300
# 103 300
# 211 300
# 19 300
# 314 300
# 310 300
# 432 300
# 485 300
# 207 300
# 214 300
# 190 300
# 185 300
# 177 300
# 127 300
# 427 300
# 206 300
# 116 300
# 116 300
# 170 300
# 141 300
# 311 300
# 119 300
# 73 300
# 223 300
# 115 300
# 64 300
# 382 300
# 81 300
# 73 300
# 167 300
# 198 300
# 81 300
# 94 300
# 134 300
# 111 300
# 342 300
# 15 300
# 117 300
# 158 300
# 217 300
# 214 300
# 341 300
# 324 300
# 70 300
# 315 300
# 94 300
# 209 300
# 393 300
# 96 300
# 126 300
# 105 300
# 287 300
# 120 300
# 163 300
# 43 300
# 38 300
# 63 300
# 565 300
# 161 300
# 148 300
# 262 300
# 171 300
# 187 300
# 224 300
# 215 300
# 144 300
# 145 300
# 7 300
# 122 300
# 91 300
# 303 300
# 204 300
# 80 300
# 144 300
# 426 300
# 70 300
# 125 300
# 156 300
# 318 300
# 286 300
# 265 300
# 104 300
# 11 300
# 146 300
# 111 300
# 106 300
# 293 300
# 20 300
# 109 300
# 106 300
# 116 300
# 312 300
# 408 300
# 110 300
# 141 300
# 175 300
# 496 300
# 362 300
# 61 300
# 178 300
# 20 300
# 108 300
# 239 300
# 69 300
# 210 300
# 200 300
# 23 300
# 591 300
# 812 300
# 433 300
# 491 300
# 494 300
# 92 300
# 126 300
# 585 300
# 325 300
# 279 300
# 245 300
# 248 300
# 53 300
# 203 300
# 176 300
# 114 300
# 74 300
# 86 300
# 144 300
# 473 300
# 283 300
# 422 300
# 214 300
# 118 300
# 360 300
# 181 300
# 159 300
# 237 300
# 184 300
# 33 300
# 366 300
# 255 300
# 131 300
# 256 300
# 232 300
# 134 300
# 150 300
# 48 300
# 93 300
# 199 300
# 128 300
# 30 300
# 367 300
# 17 300
# 373 300
# 166 300
# 251 300
# 377 300
# 230 300
# 104 300
# 359 300
# 397 300
# 110 300
# 248 300
# 9 300
# 210 300
# 147 300
# 418 300
# 45 300
# 41 300
# 97 300
# 187 300
# 235 300
# 113 300
# 94 300
# 755 300
# 299 300
# 128 300
# 183 300
# 212 300
# 112 300
# 185 300
# 277 300
# 327 300
# 80 300
# 225 300
# 166 300
# 26 300
# 23 300
# 422 300
# 258 300
# 312 300
# 109 300
# 290 300
# 108 300
# 79 300
# 141 300
# 231 300
# 183 300
# 267 300
# 299 300
# 26 300
# 256 300
# 186 300
# 318 300
# 103 300
# 320 300
# 108 300
# 360 300
# 460 300
# 5 300
# 159 300
# 449 300
# 149 300
# 55 300
# 275 300
# 252 300
# 143 300
# 291 300
# 81 300
# 159 300
# 63 300
# 201 300
# 422 300
# 145 300
# 235 300
# 136 300
# 88 300
# 362 300
# 9 300
# 103 300
# 72 300
# 100 300
# 299 300
# 282 300
# 8 300
# 162 300
# 403 300
# 257 300
# 90 300
# 10 300
# 265 300
# 381 300
# 237 300
# 97 300
# 260 300
# 92 300
# 311 300
# 163 300
# 159 300
# 153 300
# 9 300
# 189 300
# 203 300
# 122 300
# 473 300
# 126 300
# 264 300
# 107 300
# 104 300
# 331 300
# 203 300
# 61 300
# 124 300
# 244 300
# 176 300
# 132 300
# 212 300
# 448 300
# 184 300
# 261 300
# 297 300
# 45 300
# 25 300
# 94 300
# 143 300
# 267 300
# 301 300
# 220 300
# 187 300
# 437 300
# 78 300
# 286 300
# 184 300
# 151 300
# 115 300
# 394 300
# 126 300
# 348 300
# 167 300
# 309 300
# 180 300
# 292 300
# 208 300
# 179 300
# 694 300
# 39 300
# 209 300
# 182 300
# 73 300
# 222 300
# 433 300
# 197 300
# 73 300
# 267 300
# 144 300
# 520 300
# 335 300
# 16 300
# 402 300
# 53 300
# 8 300
# 154 300
# 256 300
# 233 300
# 45 300
# 156 300
# 134 300
# 9 300
# 77 300
# 2 300
# 63 300
# 376 300
# 260 300
# 265 300
# 200 300
# 275 300
# 365 300
# 229 300
# 506 300
# 104 300
# 159 300
# 338 300
# 201 300
# 301 300
# 349 300
# 154 300
# 67 300
# 159 300
# 562 300
# 311 300
# 241 300
# 116 300
# 398 300
# 252 300
# 125 300
# 202 300
# 450 300
# 316 300
# 203 300
# 254 300
# 409 300
# 113 300
# 164 300
# 366 300
# 52 300
# 84 300
# 434 300
# 207 300
# 138 300
# 405 300
# 147 300
# 195 300
# 454 300
# 213 300
# 90 300
# 98 300
# 155 300
# 388 300
# 173 300
# 142 300
# 327 300
# 230 300
# 175 300
# 189 300
# 407 300
# 50 300
# 658 300
# 92 300
# 129 300
# 537 300
# 123 300
# 125 300
# 188 300
# 212 300
# 390 300
# 274 300
# 228 300
# 62 300
# 50 300
# 197 300
# 114 300
# 160 300
# 184 300
# 144 300
# 302 300
# 163 300
# 164 300
# 153 300
# 174 300
# 70 300
# 353 300
# 512 300
# 388 300
# 323 300
# 129 300
# 330 300
# 102 300
# 100 300
# 112 300
# 389 300
# 248 300
# 190 300
# 594 300
# 7 300
# 312 300
# 320 300
# 493 300
# 394 300
# 324 300
# 238 300
# 245 300
# 122 300
# 436 300
# 329 300
# 329 300
# 38 300
# 6 300
# 287 300
# 103 300
# 83 300
# 330 300
# 136 300
# 54 300
# 150 300
# 19 300
# 231 300
# 320 300
# 126 300
# 114 300
# 91 300
# 170 300
# 198 300
# 100 300
# 147 300
# 626 300
# 77 300
# 28 300
# 90 300
# 217 300
# 267 300
# 181 300
# 449 300
# 101 300
# 94 300
# 264 300
# 108 300
# 493 300
# 101 300
# 247 300
# 165 300
# 247 300
# 202 300
# 137 300
# 150 300
# 61 300
# 282 300
# 295 300
# 14 300
# 6 300
# 76 300
# 335 300
# 140 300
# 192 300
# 28 300
# 170 300
# 244 300
# 67 300
# 174 300
# 225 300
# 286 300
# 152 300
# 113 300
# 129 300
# 407 300
# 175 300
# 369 300
# 416 300
# 195 300
# 116 300
# 255 300
# 197 300
# 300 300
# 109 300
# 275 300
# 231 300
# 89 300
# 108 300
# 477 300
# 322 300
# 177 300
# 307 300
# 131 300
# 51 300
# 122 300
# 49 300
# 238 300
# 203 300
# 329 300
# 293 300
# 365 300
# 466 300
# 107 300
# 124 300
# 560 300
# 10 300
# 127 300
# 68 300
# 424 300
# 168 300
# 187 300
# 5 300
# 25 300
# 50 300
# 343 300
# 548 300
# 101 300
# 125 300
# 34 300
# 117 300
# 37 300
# 178 300
# 140 300
# 121 300
# 195 300
# 53 300
# 282 300
# 80 300
# 368 300
# 129 300
# 245 300
# 243 300
# 738 300
# 312 300
# 273 300
# 106 300
# 337 300
# 42 300
# 108 300
# 82 300
# 22 300
# 173 300
# 126 300
# 11 300
# 509 300
# 327 300
# 243 300
# 446 300
# 72 300
# 310 300
# 353 300
# 548 300
# 268 300
# 35 300
# 97 300
# 240 300
# 182 300
# 130 300
# 240 300
# 116 300
# 303 300
# 16 300
# 96 300
# 351 300
# 315 300
# 272 300
# 117 300
# 213 300
# 166 300
# 203 300
# 111 300
# 609 300
# 57 300
# 218 300
# 28 300
# 95 300
# 51 300
# 118 300
# 327 300
# 63 300
# 179 300
# 330 300
# 572 300
# 326 300
# 102 300
# 310 300
# 597 300
# 196 300
# 137 300
# 209 300
# 200 300
# 137 300
# 71 300
# 140 300
# 294 300
# 244 300
# 182 300
# 358 300
# 199 300
# 213 300
# 30 300
# 267 300
# 30 300
# 318 300
# 273 300
# 184 300
# 160 300
# 325 300
# 164 300
# 312 300
# 123 300
# 371 300
# 69 300
# 175 300
# 190 300
# 84 300
# 307 300
# 344 300
# 369 300
# 261 300
# 289 300
# 176 300
# 238 300
# 63 300
# 373 300
# 248 300
# 244 300
# 205 300
# 353 300
# 397 300
# 178 300
# 45 300
# 108 300
# 386 300
# 70 300
# 21 300
# 361 300
# 44 300
# 263 300
# 659 300
# 72 300
# 135 300
# 61 300
# 207 300
# 185 300
# 125 300
# 55 300
# 170 300
# 18 300
# 46 300
# 252 300
# 373 300
# 37 300
# 9 300
# 325 300
# 132 300
# 183 300
# 51 300
# 364 300
# 119 300
# 442 300
# 529 300
# 196 300
# 297 300
# 186 300
# 175 300
# 318 300
# 580 300
# 6 300
# 149 300
# 51 300
# 197 300
# 287 300
# 384 300
# 215 300
# 195 300
# 179 300
# 130 300
# 131 300
# 359 300
# 206 300
# 146 300
# 284 300
# 203 300
# 134 300
# 136 300
# 151 300
# 109 300
# 93 300
# 121 300
# 172 300
# 114 300
# 123 300
# 338 300
# 86 300
# 37 300
# 235 300
# 3 300
# 186 300
# 420 300
# 21 300
# 102 300
# 93 300
# 395 300
# 63 300
# 13 300
# 292 300
# 179 300
# 112 300
# 134 300
# 105 300
# 16 300
# 320 300
# 112 300
# 75 300
# 459 300
# 64 300
# 531 300
# 220 300
# 84 300
# 51 300
# 149 300
# 306 300
# 180 300
# 204 300
# 389 300
# 689 300
# 485 300
# 385 300
# 234 300
# 295 300
# 237 300
# 160 300
# 503 300
# 82 300
# 72 300
# 181 300
# 185 300
# 136 300
# 595 300
# 207 300
# 193 300
# 19 300
# 60 300
# 117 300
# 125 300
# 272 300
# 280 300
# 74 300
# 214 300
# 189 300
# 299 300
# 156 300
# 434 300
# 226 300
# 556 300
# 122 300
# 280 300
# 343 300
# 85 300
# 145 300
# 123 300
# 362 300
# 145 300
# 387 300
# 308 300
# 385 300
# 240 300
# 294 300
# 39 300
# 273 300
# 158 300
# 186 300
# 144 300
# 183 300
# 93 300
# 19 300
# 177 300
# 121 300
# 211 300
# 74 300
# 223 300
# 360 300
# 242 300
# 139 300
# 176 300
# 178 300
# 240 300
# 195 300
# 100 300
# 93 300
# 375 300
# 222 300
# 62 300
# 239 300
# 272 300
# 208 300
# 203 300
# 271 300
# 109 300
# 189 300
# 76 300
# 84 300
# 296 300
# 251 300
# 209 300
# 303 300
# 268 300
# 144 300
# 336 300
# 523 300
# 7 300
# 163 300
# 204 300
# 266 300
# 189 300
# 152 300
# 283 300
# 190 300
# 128 300
# 144 300
# 198 300
# 163 300
# 176 300
# 189 300
# 311 300
# 260 300
# 21 300
# 239 300
# 188 300
# 130 300
# 126 300
# 140 300
# 285 300
# 249 300
# 213 300
# 267 300
# 95 300
# 130 300
# 153 300
# 72 300
# 328 300
# 307 300
# 157 300
# 71 300
# 103 300
# 250 300
# 343 300
# 296 300
# 143 300
# 419 300
# 290 300
# 16 300
# 248 300
# 14 300
# 21 300
# 234 300
# 433 300
# 316 300
# 192 300
# 161 300
# 301 300
# 71 300
# 13 300
# 124 300
# 110 300
# 355 300
# 191 300
# 110 300
# 248 300
# 51 300
# 241 300
# 198 300
# 194 300
# 123 300
# 72 300
# 89 300
# 257 300
# 187 300
# 404 300
# 305 300
# 51 300
# 13 300
# 294 300
# 563 300
# 176 300
# 513 300
# 183 300
# 172 300
# 57 300
# 183 300
# 220 300
# 101 300
# 512 300
# 88 300
# 103 300
# 149 300
# 210 300
# 203 300
# 47 300
# 5 300
# 221 300
# 82 300
# 218 300
# 245 300
# 15 300
# 269 300
# 203 300
# 478 300
# 158 300
# 286 300
# 555 300
# 300 300
# 294 300
# 154 300
# 258 300
# 475 300
# 185 300
# 356 300
# 55 300
# 346 300
# 93 300
# 305 300
# 516 300
# 14 300
# 111 300
# 14 300
# 32 300
# 161 300
# 255 300
# 356 300
# 20 300
# 187 300
# 280 300
# 6 300
# 105 300
# 301 300
# 260 300
# 92 300
# 144 300
# 158 300
# 327 300
# 295 300
# 376 300
# 215 300
# 453 300
# 145 300
# 407 300
# 177 300
# 257 300
# 108 300
# 191 300
# 464 300
# 44 300
# 242 300
# 324 300
# 372 300
# 113 300
# 146 300
# 376 300
# 156 300
# 175 300
# 398 300
# 142 300
# 59 300
# 366 300
# 325 300
# 87 300
# 275 300
# 244 300
# 263 300
# 195 300
# 49 300
# 140 300
# 108 300
# 82 300
# 64 300
# 543 300
# 249 300
# 404 300
# 203 300
# 380 300
# 7 300
# 57 300
# 112 300
# 251 300
# 20 300
# 267 300
# 307 300
# 23 300
# 85 300
# 268 300
# 14 300
# 337 300
# 253 300
# 17 300
# 123 300
# 189 300
# 303 300
# 117 300
# 692 300
# 361 300
# 161 300
# 198 300
# 123 300
# 91 300
# 9 300
# 119 300
# 150 300
# 286 300
# 85 300
# 227 300
# 119 300
# 420 300
# 266 300
# 520 300
# 269 300
# 74 300
# 108 300
# 239 300
# 86 300
# 219 300
# 295 300
# 89 300
# 104 300
# 263 300
# 154 300
# 110 300
# 135 300
# 474 300
# 40 300
# 260 300
# 225 300
# 250 300
# 40 300
# 171 300
# 225 300
# 303 300
# 73 300
# 323 300
# 256 300
# 306 300
# 153 300
# 54 300
# 389 300
# 36 300
# 324 300
# 17 300
# 76 300
# 46 300
# 8 300
# 308 300
# 202 300
# 371 300
# 312 300
# 339 300
# 145 300
# 17 300
# 469 300
# 127 300
# 69 300
# 206 300
# 196 300
# 202 300
# 100 300
# 176 300
# 9 300
# 85 300
# 349 300
# 279 300
# 279 300
# 123 300
# 55 300
# 278 300
# 207 300
# 178 300
# 158 300
# 141 300
# 221 300
# 108 300
# 741 300
# 39 300
# 204 300
# 136 300
# 282 300
# 116 300
# 193 300
# 306 300
# 325 300
# 155 300
# 57 300
# 618 300
# 199 300
# 100 300
# 97 300
# 94 300
# 328 300
# 267 300
# 297 300
# 301 300
# 174 300
# 385 300
# 364 300
# 71 300
# 182 300
# 110 300
# 180 300
# 223 300
# 364 300
# 289 300
# 228 300
# 117 300
# 330 300
# 83 300
# 9 300
# 206 300
# 31 300
# 236 300
# 50 300
# 272 300
# 224 300
# 26 300
# 253 300
# 112 300
# 112 300
# 260 300
# 330 300
# 222 300
# 230 300
# 305 300
# 142 300
# 460 300
# 415 300
# 166 300
# 242 300
# 84 300
# 150 300
# 136 300
# 373 300
# 7 300
# 33 300
# 210 300
# 118 300
# 76 300
# 343 300
# 170 300
# 457 300
# 119 300
# 204 300
# 91 300
# 386 300
# 157 300
# 43 300
# 290 300
# 184 300
# 57 300
# 208 300
# 119 300
# 561 300
# 273 300
# 256 300
# 357 300
# 87 300
# 128 300
# 172 300
# 27 300
# 340 300
# 244 300
# 68 300
# 353 300
# 240 300
# 237 300
# 173 300
# 65 300
# 234 300
# 285 300
# 151 300
# 154 300
# 109 300
# 108 300
# 152 300
# 271 300
# 374 300
# 158 300
# 167 300
# 105 300
# 193 300
# 119 300
# 391 300
# 99 300
# 294 300
# 233 300
# 160 300
# 324 300
# 267 300
# 442 300
# 260 300
# 6 300
# 154 300
# 93 300
# 113 300
# 339 300
# 54 300
# 182 300
# 171 300
# 220 300
# 158 300
# 173 300
# 201 300
# 157 300
# 509 300
# 98 300
# 234 300
# 17 300
# 314 300
# 162 300
# 257 300
# 390 300
# 92 300
# 40 300
# 192 300
# 107 300
# 361 300
# 176 300
# 133 300
# 93 300
# 417 300
# 164 300
# 592 300
# 437 300
# 319 300
# 172 300
# 227 300
# 218 300
# 130 300
# 231 300
# 23 300
# 117 300
# 144 300
# 73 300
# 168 300
# 11 300
# 233 300
# 214 300
# 389 300
# 361 300
# 282 300
# 78 300
# 573 300
# 246 300
# 226 300
# 325 300
# 89 300
# 252 300
# 100 300
# 138 300
# 68 300
# 164 300
# 411 300
# 306 300
# 92 300
# 173 300
# 80 300
# 273 300
# 211 300
# 133 300
# 303 300
# 70 300
# 201 300
# 151 300
# 266 300
# 245 300
# 251 300
# 319 300
# 132 300
# 589 300
# 244 300
# 9 300
# 178 300
# 344 300
# 261 300
# 421 300
# 180 300
# 161 300
# 221 300
# 437 300
# 203 300
# 194 300
# 268 300
# 25 300
# 68 300
# 238 300
# 181 300
# 181 300
# 239 300
# 188 300
# 275 300
# 245 300
# 149 300
# 391 300
# 149 300
# 251 300
# 497 300
# 255 300
# 248 300
# 354 300
# 233 300
# 150 300
# 123 300
# 350 300
# 203 300
# 189 300
# 120 300
# 172 300
# 130 300
# 217 300
# 438 300
# 58 300
# 13 300
# 231 300
# 75 300
# 226 300
# 198 300
# 223 300
# 363 300
# 280 300
# 9 300
# 329 300
# 251 300
# 323 300
# 103 300
# 316 300
# 212 300
# 493 300
# 713 300
# 201 300
# 146 300
# 96 300
# 95 300
# 95 300
# 77 300
# 286 300
# 9 300
# 371 300
# 83 300
# 208 300
# 379 300
# 280 300
# 165 300
# 38 300
# 70 300
# 305 300
# 329 300
# 330 300
# 293 300
# 115 300
# 444 300
# 419 300
# 291 300
# 172 300
# 166 300
# 122 300
# 140 300
# 150 300
# 87 300
# 14 300
# 116 300
# 208 300
# 682 300
# 96 300
# 50 300
# 92 300
# 538 300
# 237 300
# 219 300
# 328 300
# 317 300
# 262 300
# 97 300
# 200 300
# 171 300
# 102 300
# 293 300
# 289 300
# 67 300
# 47 300
# 122 300
# 155 300
# 329 300
# 206 300
# 810 300
# 51 300
# 28 300
# 179 300
# 80 300
# 211 300
# 91 300
# 210 300
# 913 300
# 182 300
# 96 300
# 336 300
# 158 300
# 320 300
# 265 300
# 36 300
# 128 300
# 187 300
# 170 300
# 38 300
# 101 300
# 126 300
# 451 300
# 79 300
# 125 300
# 281 300
# 277 300
# 232 300
# 88 300
# 295 300
# 199 300
# 202 300
# 59 300
# 149 300
# 206 300
# 9 300
# 226 300
# 129 300
# 66 300
# 139 300
# 255 300
# 191 300
# 220 300
# 207 300
# 215 300
# 263 300
# 212 300
# 18 300
# 191 300
# 81 300
# 95 300
# 109 300
# 466 300
# 74 300
# 11 300
# 49 300
# 467 300
# 34 300
# 203 300
# 25 300
# 124 300
# 69 300
# 186 300
# 177 300
# 164 300
# 399 300
# 231 300
# 452 300
# 251 300
# 552 300
# 181 300
# 294 300
# 269 300
# 375 300
# 190 300
# 312 300
# 8 300
# 139 300
# 285 300
# 429 300
# 456 300
# 118 300
# 194 300
# 15 300
# 66 300
# 251 300
# 350 300
# 536 300
# 78 300
# 198 300
# 95 300
# 172 300
# 223 300
# 206 300
# 548 300
# 95 300
# 107 300
# 324 300
# 50 300
# 179 300
# 18 300
# 91 300
# 10 300
# 100 300
# 190 300
# 61 300
# 171 300
# 90 300
# 505 300
# 140 300
# 291 300
# 454 300
# 748 300
# 58 300
# 379 300
# 7 300
# 122 300
# 204 300
# 92 300
# 9 300
# 222 300
# 197 300
# 442 300
# 88 300
# 147 300
# 129 300
# 343 300
# 233 300
# 331 300
# 201 300
# 138 300
# 251 300
# 231 300
# 170 300
# 20 300
# 283 300
# 349 300
# 89 300
# 267 300
# 343 300
# 78 300
# 111 300
# 45 300
# 111 300
# 247 300
# 121 300
# 491 300
# 565 300
# 214 300
# 77 300
# 439 300
# 61 300
# 486 300
# 29 300
# 98 300
# 190 300
# 144 300
# 349 300
# 133 300
# 452 300
# 327 300
# 338 300
# 132 300
# 346 300
# 117 300
# 181 300
# 23 300
# 12 300
# 120 300
# 254 300
# 75 300
# 287 300
# 223 300
# 9 300
# 127 300
# 184 300
# 176 300
# 273 300
# 190 300
# 120 300
# 117 300
# 220 300
# 96 300
# 387 300
# 116 300
# 237 300
# 256 300
# 76 300
# 53 300
# 311 300
# 213 300
# 179 300
# 227 300
# 85 300
# 95 300
# 83 300
# 316 300
# 381 300
# 343 300
# 139 300
# 130 300
# 359 300
# 104 300
# 622 300
# 285 300
# 207 300
# 177 300
# 172 300
# 31 300
# 111 300
# 475 300
# 240 300
# 117 300
# 20 300
# 77 300
# 122 300
# 288 300
# 357 300
# 180 300
# 253 300
# 419 300
# 283 300
# 212 300
# 107 300
# 208 300
# 2 300
# 69 300
# 130 300
# 284 300
# 99 300
# 294 300
# 9 300
# 78 300
# 34 300
# 328 300
# 136 300
# 206 300
# 461 300
# 21 300
# 148 300
# 215 300
# 287 300
# 86 300
# 202 300
# 164 300
# 134 300
# 53 300
# 295 300
# 262 300
# 252 300
# 260 300
# 205 300
# 8 300
# 181 300
# 297 300
# 102 300
# 749 300
# 15 300
# 363 300
# 107 300
# 155 300
# 145 300
# 223 300
# 377 300
# 320 300
# 191 300
# 278 300
# 220 300
# 371 300
# 166 300
# 130 300
# 161 300
# 207 300
# 39 300
# 257 300
# 104 300
# 127 300
# 190 300
# 151 300
# 120 300
# 278 300
# 266 300
# 217 300
# 108 300
# 266 300
# 211 300
# 481 300
# 262 300
# 529 300
# 188 300
# 58 300
# 195 300
# 334 300
# 291 300
# 89 300
# 7 300
# 55 300
# 159 300
# 130 300
# 422 300
# 241 300
# 12 300
# 176 300
# 92 300
# 76 300
# 9 300
# 506 300
# 336 300
# 271 300
# 106 300
# 68 300
# 8 300
# 55 300
# 289 300
# 446 300
# 243 300
# 565 300
# 290 300
# 11 300
# 151 300
# 1 300
# 453 300
# 378 300
# 17 300
# 251 300
# 188 300
# 226 300
# 203 300
# 473 300
# 420 300
# 146 300
# 63 300
# 352 300
# 410 300
# 301 300
# 74 300
# 92 300
# 104 300
# 462 300
# 216 300
# 40 300
# 642 300
# 262 300
# 84 300
# 154 300
# 101 300
# 71 300
# 340 300
# 349 300
# 115 300
# 111 300
# 24 300
# 418 300
# 29 300
# 233 300
# 219 300
# 172 300
# 158 300
# 344 300
# 70 300
# 56 300
# 121 300
# 132 300
# 273 300
# 48 300
# 138 300
# 117 300
# 179 300
# 138 300
# 456 300
# 153 300
# 37 300
# 15 300
# 185 300
# 359 300
# 288 300
# 39 300
# 216 300
# 278 300
# 298 300
# 144 300
# 109 300
# 218 300
# 170 300
# 105 300
# 88 300
# 222 300
# 220 300
# 342 300
# 74 300
# 71 300
# 215 300
# 278 300
# 182 300
# 107 300
# 114 300
# 191 300
# 375 300
# 290 300
# 296 300
# 288 300
# 22 300
# 203 300
# 221 300
# 357 300
# 286 300
# 172 300
# 233 300
# 228 300
# 272 300
# 18 300
# 16 300
# 288 300
# 242 300
# 87 300
# 189 300
# 219 300
# 135 300
# 71 300
# 274 300
# 45 300
# 33 300
# 672 300
# 136 300
# 283 300
# 92 300
# 75 300
# 244 300
# 51 300
# 110 300
# 39 300
# 21 300
# 455 300
# 85 300
# 391 300
# 10 300
# 144 300
# 165 300
# 9 300
# 220 300
# 93 300
# 83 300
# 236 300
# 73 300
# 165 300
# 428 300
# 225 300
# 39 300
# 60 300
# 149 300
# 287 300
# 11 300
# 798 300
# 295 300
# 76 300
# 265 300
# 372 300
# 115 300
# 391 300
# 347 300
# 86 300
# 297 300
# 472 300
# 59 300
# 219 300
# 46 300
# 296 300
# 231 300
# 233 300
# 69 300
# 380 300
# 119 300
# 238 300
# 260 300
# 179 300
# 212 300
# 137 300
# 287 300
# 359 300
# 38 300
# 172 300
# 260 300
# 288 300
# 150 300
# 243 300
# 211 300
# 380 300
# 31 300
# 122 300
# 102 300
# 185 300
# 207 300
# 220 300
# 176 300
# 462 300
# 400 300
# 166 300
# 255 300
# 376 300
# 463 300
# 109 300
# 156 300
# 326 300
# 275 300
# 292 300
# 173 300
# 68 300
# 340 300
# 39 300
# 260 300
# 120 300
# 123 300
# 199 300
# 233 300
# 12 300
# 70 300
# 87 300
# 244 300
# 172 300
# 144 300
# 106 300
# 115 300
# 249 300
# 281 300
# 309 300
# 72 300
# 91 300
# 260 300
# 47 300
# 42 300
# 93 300
# 447 300
# 311 300
# 212 300
# 117 300
# 168 300
# 182 300
# 182 300
# 207 300
# 119 300
# 179 300
# 7 300
# 184 300
# 131 300
# 229 300
# 161 300
# 290 300
# 549 300
# 245 300
# 161 300
# 188 300
# 220 300
# 36 300
# 116 300
# 48 300
# 538 300
# 287 300
# 64 300
# 198 300
# 97 300
# 122 300
# 249 300
# 255 300
# 225 300
# 386 300
# 362 300
# 95 300
# 357 300
# 22 300
# 5 300
# 329 300
# 215 300
# 261 300
# 52 300
# 47 300
# 100 300
# 234 300
# 148 300
# 228 300
# 74 300
# 385 300
# 439 300
# 121 300
# 130 300
# 278 300
# 198 300
# 278 300
# 209 300
# 202 300
# 151 300
# 266 300
# 344 300
# 183 300
# 306 300
# 234 300
# 267 300
# 264 300
# 131 300
# 195 300
# 749 300
# 106 300
# 330 300
# 80 300
# 406 300
# 73 300
# 198 300
# 384 300
# 51 300
# 14 300
# 294 300
# 244 300
# 394 300
# 340 300
# 49 300
# 114 300
# 203 300
# 108 300
# 196 300
# 229 300
# 159 300
# 263 300
# 190 300
# 10 300
# 271 300
# 176 300
# 22 300
# 261 300
# 56 300
# 99 300
# 214 300
# 176 300
# 216 300
# 182 300
# 267 300
# 235 300
# 43 300
# 59 300
# 220 300
# 136 300
# 281 300
# 333 300
# 234 300
# 145 300
# 433 300
# 16 300
# 288 300
# 205 300
# 161 300
# 202 300
# 155 300
# 131 300
# 102 300
# 151 300
# 167 300
# 225 300
# 248 300
# 301 300
# 449 300
# 51 300
# 567 300
# 51 300
# 274 300
# 295 300
# 106 300
# 322 300
# 111 300
# 230 300
# 482 300
# 250 300
# 71 300
# 167 300
# 318 300
# 206 300
# 114 300
# 244 300
# 179 300
# 312 300
# 167 300
# 180 300
# 128 300
# 235 300
# 90 300
# 119 300
# 235 300
# 124 300
# 106 300
# 347 300
# 181 300
# 62 300
# 76 300
# 172 300
# 68 300
# 266 300
# 287 300
# 78 300
# 107 300
# 166 300
# 408 300
# 186 300
# 280 300
# 418 300
# 206 300
# 133 300
# 124 300
# 139 300
# 329 300
# 214 300
# 32 300
# 104 300
# 102 300
# 375 300
# 337 300
# 51 300
# 89 300
# 64 300
# 443 300
# 206 300
# 63 300
# 240 300
# 295 300
# 91 300
# 340 300
# 71 300
# 230 300
# 146 300
# 472 300
# 84 300
# 96 300
# 385 300
# 60 300
# 103 300
# 162 300
# 138 300
# 601 300
# 296 300
# 79 300
# 67 300
# 99 300
# 455 300
# 173 300
# 174 300
# 200 300
# 154 300
# 195 300
# 251 300
# 249 300
# 103 300
# 193 300
# 319 300
# 367 300
# 75 300
# 356 300
# 213 300
# 127 300
# 214 300
# 118 300
# 134 300
# 97 300
# 235 300
# 147 300
# 80 300
# 419 300
# 65 300
# 196 300
# 504 300
# 177 300
# 134 300
# 101 300
# 252 300
# 156 300
# 212 300
# 230 300
# 787 300
# 230 300
# 127 300
# 246 300
# 441 300
# 269 300
# 352 300
# 107 300
# 219 300
# 364 300
# 467 300
# 218 300
# 42 300
# 471 300
# 208 300
# 74 300
# 144 300
# 246 300
# 552 300
# 98 300
# 199 300
# 251 300
# 138 300
# 182 300
# 393 300
# 290 300
# 277 300
# 562 300
# 36 300
# 9 300
# 372 300
# 344 300
# 143 300
# 152 300
# 601 300
# 140 300
# 31 300
# 383 300
# 62 300
# 239 300
# 116 300
# 184 300
# 45 300
# 188 300
# 192 300
# 571 300
# 537 300
# 208 300
# 392 300
# 364 300
# 307 300
# 281 300
# 131 300
# 538 300
# 59 300
# 312 300
# 85 300
# 15 300
# 94 300
# 279 300
# 59 300
# 68 300
# 226 300
# 251 300
# 9 300
# 176 300
# 80 300
# 212 300
# 300 300
# 184 300
# 281 300
# 238 300
# 57 300
# 178 300
# 124 300
# 209 300
# 185 300
# 95 300
# 337 300
# 169 300
# 299 300
# 225 300
# 156 300
# 370 300
# 44 300
# 285 300
# 104 300
# 241 300
# 202 300
# 58 300
# 568 300
# 219 300
# 164 300
# 172 300
# 201 300
# 228 300
# 74 300
# 492 300
# 143 300
# 153 300
# 167 300
# 304 300
# 69 300
# 378 300
# 42 300
# 377 300
# 129 300
# 124 300
# 144 300
# 163 300
# 355 300
# 774 300
# 6 300
# 7 300
# 594 300
# 16 300
# 179 300
# 100 300
# 220 300
# 434 300
# 108 300
# 189 300
# 210 300
# 163 300
# 103 300
# 310 300
# 242 300
# 151 300
# 125 300
# 203 300
# 111 300
# 70 300
# 149 300
# 47 300
# 199 300
# 42 300
# 105 300
# 249 300
# 19 300
# 16 300
# 246 300
# 131 300
# 42 300
# 334 300
# 355 300
# 94 300
# 182 300
# 349 300
# 441 300
# 31 300
# 319 300
# 249 300
# 328 300
# 277 300
# 434 300
# 190 300
# 101 300
# 204 300
# 516 300
# 112 300
# 294 300
# 94 300
# 50 300
# 435 300
# 176 300
# 172 300
# 100 300
# 186 300
# 229 300
# 231 300
# 303 300
# 228 300
# 215 300
# 111 300
# 204 300
# 104 300
# 52 300
# 190 300
# 107 300
# 17 300
# 152 300
# 348 300
# 322 300
# 222 300
# 282 300
# 7 300
# 254 300
# 387 300
# 234 300
# 361 300
# 71 300
# 461 300
# 89 300
# 374 300
# 196 300
# 355 300
# 104 300
# 171 300
# 103 300
# 164 300
# 167 300
# 291 300
# 145 300
# 248 300
# 104 300
# 116 300
# 374 300
# 344 300
# 20 300
# 28 300
# 188 300
# 233 300
# 261 300
# 204 300
# 231 300
# 278 300
# 174 300
# 233 300
# 502 300
# 280 300
# 425 300
# 108 300
# 443 300
# 81 300
# 120 300
# 106 300
# 147 300
# 304 300
# 147 300
# 81 300
# 224 300
# 148 300
# 90 300
# 208 300
# 221 300
# 159 300
# 312 300
# 228 300
# 240 300
# 184 300
# 108 300
# 410 300
# 269 300
# 69 300
# 90 300
# 241 300
# 153 300
# 110 300
# 224 300
# 80 300
# 162 300
# 228 300
# 276 300
# 342 300
# 125 300
# 124 300
# 510 300
# 105 300
# 278 300
# 101 300
# 181 300
# 58 300
# 184 300
# 73 300
# 447 300
# 274 300
# 221 300
# 237 300
# 15 300
# 154 300
# 457 300
# 185 300
# 203 300
# 258 300
# 176 300
# 236 300
# 68 300
# 302 300
# 280 300
# 184 300
# 26 300
# 201 300
# 207 300
# 181 300
# 326 300
# 155 300
# 52 300
# 110 300
# 147 300
# 262 300
# 250 300
# 225 300
# 441 300
# 95 300
# 639 300
# 418 300
# 141 300
# 83 300
# 66 300
# 100 300
# 84 300
# 62 300
# 271 300
# 278 300
# 58 300
# 304 300
# 67 300
# 21 300
# 128 300
# 155 300
# 49 300
# 331 300
# 702 300
# 358 300
# 316 300
# 219 300
# 325 300
# 153 300
# 260 300
# 310 300
# 10 300
# 108 300
# 571 300
# 129 300
# 393 300
# 442 300
# 10 300
# 357 300
# 304 300
# 79 300
# 74 300
# 126 300
# 75 300
# 145 300
# 178 300
# 205 300
# 279 300
# 43 300
# 70 300
# 125 300
# 74 300
# 114 300
# 228 300
# 420 300
# 302 300
# 162 300
# 206 300
# 77 300
# 125 300
# 405 300
# 74 300
# 96 300
# 196 300
# 20 300
# 108 300
# 37 300
# 141 300
# 160 300
# 271 300
# 81 300
# 166 300
# 104 300
# 93 300
# 106 300
# 116 300
# 284 300
# 199 300
# 188 300
# 3 300
# 111 300
# 116 300
# 152 300
# 439 300
# 252 300
# 220 300
# 511 300
# 381 300
# 203 300
# 163 300
# 419 300
# 209 300
# 231 300
# 439 300
# 281 300
# 447 300
# 365 300
# 666 300
# 18 300
# 329 300
# 372 300
# 386 300
# 5 300
# 232 300
# 189 300
# 176 300
# 355 300
# 315 300
# 183 300
# 156 300
# 603 300
# 148 300
# 119 300
# 173 300
# 243 300
# 308 300
# 12 300
# 216 300
# 258 300
# 123 300
# 170 300
# 269 300
# 17 300
# 46 300
# 159 300
# 86 300
# 419 300
# 261 300
# 198 300
# 75 300
# 163 300
# 183 300
# 148 300
# 94 300
# 165 300
# 436 300
# 48 300
# 338 300
# 45 300
# 283 300
# 164 300
# 89 300
# 270 300
# 418 300
# 193 300
# 20 300
# 321 300
# 178 300
# 28 300
# 216 300
# 340 300
# 6 300
# 64 300
# 87 300
# 114 300
# 203 300
# 189 300
# 267 300
# 264 300
# 35 300
# 282 300
# 25 300
# 21 300
# 310 300
# 182 300
# 229 300
# 56 300
# 175 300
# 110 300
# 205 300
# 229 300
# 11 300
# 127 300
# 485 300
# 238 300
# 132 300
# 17 300
# 183 300
# 160 300
# 136 300
# 206 300
# 114 300
# 234 300
# 273 300
# 88 300
# 388 300
# 468 300
# 222 300
# 276 300
# 240 300
# 208 300
# 242 300
# 193 300
# 502 300
# 90 300
# 130 300
# 133 300
# 111 300
# 131 300
# 293 300
# 291 300
# 21 300
# 151 300
# 123 300
# 487 300
# 197 300
# 102 300
# 55 300
# 372 300
# 162 300
# 119 300
# 295 300
# 237 300
# 153 300
# 199 300
# 172 300
# 273 300
# 261 300
# 167 300
# 232 300
# 509 300
# 33 300
# 281 300
# 197 300
# 259 300
# 183 300
# 545 300
# 341 300
# 246 300
# 112 300
# 219 300
# 280 300
# 176 300
# 145 300
# 139 300
# 161 300
# 196 300
# 223 300
# 71 300
# 162 300
# 177 300
# 25 300
# 103 300
# 9 300
# 192 300
# 198 300
# 118 300
# 434 300
# 194 300
# 615 300
# 147 300
# 253 300
# 97 300
# 12 300
# 307 300
# 367 300
# 261 300
# 60 300
# 158 300
# 336 300
# 238 300
# 335 300
# 229 300
# 104 300
# 12 300
# 285 300
# 98 300
# 251 300
# 213 300
# 289 300
# 193 300
# 60 300
# 48 300
# 210 300
# 262 300
# 124 300
# 310 300
# 337 300
# 350 300
# 506 300
# 379 300
# 134 300
# 199 300
# 347 300
# 270 300
# 81 300
# 85 300
# 157 300
# 165 300
# 135 300
# 11 300
# 208 300
# 165 300
# 248 300
# 165 300
# 125 300
# 556 300
# 243 300
# 346 300
# 192 300
# 156 300
# 150 300
# 345 300
# 223 300
# 197 300
# 376 300
# 333 300
# 431 300
# 154 300
# 102 300
# 12 300
# 85 300
# 30 300
# 182 300
# 313 300
# 174 300
# 9 300
# 269 300
# 424 300
# 255 300
# 148 300
# 52 300
# 314 300
# 379 300
# 556 300
# 354 300
# 312 300
# 139 300
# 274 300
# 110 300
# 268 300
# 91 300
# 148 300
# 180 300
# 133 300
# 409 300
# 155 300
# 20 300
# 102 300
# 120 300
# 35 300
# 4 300
# 346 300
# 533 300
# 280 300
# 273 300
# 168 300
# 97 300
# 259 300
# 82 300
# 98 300
# 234 300
# 186 300
# 210 300
# 89 300
# 457 300
# 399 300
# 95 300
# 9 300
# 152 300
# 141 300
# 85 300
# 60 300
# 113 300
# 120 300
# 308 300
# 248 300
# 269 300
# 177 300
# 184 300
# 241 300
# 264 300
# 95 300
# 224 300
# 132 300
# 19 300
# 141 300
# 185 300
# 112 300
# 287 300
# 296 300
# 183 300
# 187 300
# 97 300
# 235 300
# 168 300
# 430 300
# 197 300
# 151 300
# 118 300
# 230 300
# 136 300
# 206 300
# 234 300
# 224 300
# 28 300
# 176 300
# 173 300
# 142 300
# 227 300
# 284 300
# 592 300
# 115 300
# 404 300
# 307 300
# 79 300
# 165 300
# 175 300
# 251 300
# 111 300
# 292 300
# 147 300
# 54 300
# 33 300
# 209 300
# 58 300
# 455 300
# 337 300
# 371 300
# 138 300
# 118 300
# 129 300
# 220 300
# 108 300
# 248 300
# 366 300
# 282 300
# 350 300
# 408 300
# 440 300
# 46 300
# 207 300
# 142 300
# 431 300
# 302 300
# 175 300
# 123 300
# 127 300
# 242 300
# 134 300
# 9 300
# 216 300
# 69 300
# 216 300
# 126 300
# 321 300
# 157 300
# 70 300
# 214 300
# 145 300
# 166 300
# 472 300
# 298 300
# 243 300
# 53 300
# 102 300
# 7 300
# 451 300
# 222 300
# 54 300
# 209 300
# 233 300
# 186 300
# 149 300
# 188 300
# 290 300
# 132 300
# 162 300
# 119 300
# 159 300
# 397 300
# 535 300
# 86 300
# 163 300
# 140 300
# 250 300
# 240 300
# 377 300
# 94 300
# 236 300
# 66 300
# 182 300
# 289 300
# 74 300
# 146 300
# 39 300
# 416 300
# 105 300
# 494 300
# 248 300
# 28 300
# 184 300
# 372 300
# 9 300
# 361 300
# 70 300
# 358 300
# 68 300
# 195 300
# 277 300
# 14 300
# 69 300
# 43 300
# 156 300
# 326 300
# 110 300
# 465 300
# 22 300
# 261 300
# 384 300
# 131 300
# 88 300
# 364 300
# 55 300
# 501 300
# 141 300
# 12 300
# 387 300
# 160 300
# 182 300
# 99 300
# 73 300
# 199 300
# 223 300
# 279 300
# 157 300
# 112 300
# 2 300
# 251 300
# 263 300
# 208 300
# 21 300
# 233 300
# 193 300
# 5 300
# 231 300
# 137 300
# 154 300
# 189 300
# 334 300
# 440 300
# 475 300
# 163 300
# 259 300
# 319 300
# 55 300
# 66 300
# 176 300
# 201 300
# 394 300
# 98 300
# 187 300
# 149 300
# 100 300
# 505 300
# 26 300
# 92 300
# 120 300
# 127 300
# 17 300
# 282 300
# 113 300
# 252 300
# 115 300
# 220 300
# 48 300
# 136 300
# 124 300
# 93 300
# 60 300
# 314 300
# 249 300
# 153 300
# 145 300
# 158 300
# 250 300
# 241 300
# 77 300
# 34 300
# 228 300
# ...
# 202 300
# 174 300
# 310 300
# 103 300
# 172 300
# 210 300
# 24 300
# 324 300
# 237 300
# 245 300
# 244 300
# 96 300
# 294 300
# 62 300
# 258 300
# 159 300
# 229 300
# 228 300
# 47 300
# 129 300
# 43 300
# 149 300
# 122 300
# 197 300
# 17 300
# 257 300
# 332 300
# 5 300
# 156 300
# 230 300
# 174 300
# 394 300
# 200 300
# 166 300
# 166 300
# 51 300
# 45 300
# 283 300
# 212 300
# 158 300
# 216 300
# 350 300
# 20 300
# 180 300
# 112 300
# 499 300
# 352 300
# 161 300
# 73 300
# 31 300
# 353 300
# 286 300
# 203 300
# 228 300
# 205 300
# 234 300
# 21 300
# 267 300
# 414 300
# 236 300
# 283 300
# 201 300
# 291 300
# 125 300
# 130 300
# 114 300
# 297 300
# 473 300
# 163 300
# 298 300
# 558 300
# 8 300
# 316 300
# 379 300
# 96 300
# 66 300
# 145 300
# 165 300
# 74 300
# 136 300
# 322 300
# 161 300
# 87 300
# 213 300
# 66 300
# 18 300
# 362 300
# 286 300
# 152 300
# 215 300
# 66 300
# 499 300
# 100 300
# 204 300
# 327 300
# 133 300
# 66 300
# 180 300
# 251 300
# 247 300
# 401 300
# 101 300
# 40 300
# 402 300
# 478 300
# 32 300
# 249 300
# 192 300
# 232 300
# 173 300
# 154 300
# 252 300
# 172 300
# 214 300
# 100 300
# 398 300
# 212 300
# 172 300
# 127 300
# 12 300
# 163 300
# 244 300
# 190 300
# 102 300
# 294 300
# 275 300
# 276 300
# 209 300
# 512 300
# 200 300
# 345 300
# 153 300
# 223 300
# 145 300
# 481 300
# 425 300
# 329 300
# 174 300
# 114 300
# 111 300
# 496 300
# 8 300
# 242 300
# 55 300
# 61 300
# 268 300
# 179 300
# 19 300
# 101 300
# 324 300
# 457 300
# 340 300
# 258 300
# 29 300
# 172 300
# 145 300
# 158 300
# 371 300
# 224 300
# 228 300
# 198 300
# 104 300
# 358 300
# 337 300
# 179 300
# 113 300
# 203 300
# 231 300
# 123 300
# 161 300
# 857 300
# 75 300
# 93 300
# 85 300
# 323 300
# 434 300
# 224 300
# 227 300
# 140 300
# 71 300
# 224 300
# 346 300
# 207 300
# 439 300
# 156 300
# 120 300
# 220 300
# 203 300
# 181 300
# 130 300
# 213 300
# 193 300
# 11 300
# 172 300
# 203 300
# 143 300
# 196 300
# 98 300
# 346 300
# 17 300
# 465 300
# 145 300
# 280 300
# 191 300
# 244 300
# 51 300
# 286 300
# 221 300
# 190 300
# 148 300
# 123 300
# 51 300
# 313 300
# 436 300
# 161 300
# 94 300
# 154 300
# 231 300
# 412 300
# 184 300
# 45 300
# 137 300
# 28 300
# 161 300
# 242 300
# 302 300
# 186 300
# 275 300
# 174 300
# 559 300
# 160 300
# 138 300
# 11 300
# 244 300
# 241 300
# 608 300
# 66 300
# 261 300
# 100 300
# 177 300
# 175 300
# 125 300
# 84 300
# 161 300
# 150 300
# 130 300
# 303 300
# 317 300
# 49 300
# 101 300
# 548 300
# 398 300
# 155 300
# 491 300
# 180 300
# 215 300
# 41 300
# 61 300
# 80 300
# 84 300
# 140 300
# 156 300
# 5 300
# 321 300
# 301 300
# 218 300
# 290 300
# 181 300
# 94 300
# 278 300
# 504 300
# 102 300
# 177 300
# 179 300
# 61 300
# 403 300
# 63 300
# 137 300
# 86 300
# 284 300
# 9 300
# 149 300
# 235 300
# 339 300
# 233 300
# 377 300
# 128 300
# 113 300
# 332 300
# 594 300
# 200 300
# 14 300
# 190 300
# 205 300
# 69 300
# 207 300
# 245 300
# 241 300
# 90 300
# 321 300
# 197 300
# 205 300
# 235 300
# 148 300
# 176 300
# 259 300
# 108 300
# 9 300
# 171 300
# 108 300
# 398 300
# 690 300
# 219 300
# 286 300
# 103 300
# 347 300
# 24 300
# 298 300
# 178 300
# 152 300
# 292 300
# 12 300
# 214 300
# 137 300
# 203 300
# 172 300
# 176 300
# 548 300
# 207 300
# 266 300
# 186 300
# 44 300
# 343 300
# 74 300
# 269 300
# 222 300
# 80 300
# 237 300
# 318 300
# 172 300
# 76 300
# 269 300
# 141 300
# 327 300
# 87 300
# 292 300
# 271 300
# 634 300
# 115 300
# 2 300
# 214 300
# 240 300
# 351 300
# 308 300
# 86 300
# 303 300
# 298 300
# 181 300
# 59 300
# 123 300
# 154 300
# 97 300
# 229 300
# 320 300
# 244 300
# 130 300
# 331 300
# 160 300
# 235 300
# 192 300
# 69 300
# 329 300
# 447 300
# 160 300
# 122 300
# 276 300
# 157 300
# 235 300
# 304 300
# 197 300
# 234 300
# 429 300
# 646 300
# 14 300
# 54 300
# 25 300
# 28 300
# 112 300
# 135 300
# 127 300
# 9 300
# 221 300
# 312 300
# 153 300
# 252 300
# 395 300
# 108 300
# 175 300
# 705 300
# 164 300
# 231 300
# 323 300
# 417 300
# 9 300
# 425 300
# 23 300
# 79 300
# 186 300
# 240 300
# 117 300
# 52 300
# 383 300
# 298 300
# 181 300
# 324 300
# 205 300
# 213 300
# 69 300
# 104 300
# 135 300
# 27 300
# 90 300
# 297 300
# 171 300
# 119 300
# 191 300
# 216 300
# 221 300
# 250 300
# 222 300
# 356 300
# 185 300
# 142 300
# 347 300
# 169 300
# 45 300
# 80 300
# 187 300
# 307 300
# 149 300
# 169 300
# 207 300
# 160 300
# 93 300
# 296 300
# 79 300
# 492 300
# 187 300
# 277 300
# 312 300
# 230 300
# 129 300
# 110 300
# 196 300
# 426 300
# 113 300
# 176 300
# 197 300
# 292 300
# 40 300
# 323 300
# 373 300
# 13 300
# 265 300
# 101 300
# 446 300
# 542 300
# 432 300
# 117 300
# 6 300
# 408 300
# 291 300
# 293 300
# 347 300
# 294 300
# 407 300
# 86 300
# 263 300
# 181 300
# 323 300
# 80 300
# 330 300
# 107 300
# 197 300
# 189 300
# 332 300
# 172 300
# 118 300
# 29 300
# 359 300
# 129 300
# 418 300
# 371 300
# 636 300
# 413 300
# 259 300
# 174 300
# 80 300
# 33 300
# 76 300
# 159 300
# 81 300
# 70 300
# 243 300
# 122 300
# 204 300
# 342 300
# 366 300
# 419 300
# 62 300
# 516 300
# 278 300
# 132 300
# 262 300
# 297 300
# 97 300
# 206 300
# 182 300
# 6 300
# 323 300
# 318 300
# 75 300
# 361 300
# 15 300
# 106 300
# 273 300
# 547 300
# 77 300
# 231 300
# 460 300
# 387 300
# 339 300
# 169 300
# 45 300
# 192 300
# 407 300
# 143 300
# 197 300
# 377 300
# 119 300
# 86 300
# 113 300
# 259 300
# 288 300
# 192 300
# 155 300
# 128 300
# 192 300
# 379 300
# 211 300
# 85 300
# 34 300
# 238 300
# 282 300
# 102 300
# 111 300
# 401 300
# 275 300
# 63 300
# 266 300
# 121 300
# 816 300
# 169 300
# 130 300
# 185 300
# 366 300
# 531 300
# 200 300
# 116 300
# 401 300
# 227 300
# 132 300
# 243 300
# 164 300
# 420 300
# 428 300
# 358 300
# 468 300
# 16 300
# 394 300
# 170 300
# 219 300
# 358 300
# 279 300
# 74 300
# 320 300
# 148 300
# 69 300
# 142 300
# 280 300
# 297 300
# 124 300
# 174 300
# 506 300
# 184 300
# 87 300
# 264 300
# 201 300
# 230 300
# 273 300
# 71 300
# 228 300
# 75 300
# 270 300
# 98 300
# 131 300
# 329 300
# 200 300
# 271 300
# 247 300
# 184 300
# 23 300
# 54 300
# 161 300
# 233 300
# 207 300
# 240 300
# 88 300
# 121 300
# 83 300
# 8 300
# 211 300
# 343 300
# 11 300
# 244 300
# 313 300
# 199 300
# 150 300
# 316 300
# 57 300
# 328 300
# 460 300
# 338 300
# 96 300
# 82 300
# 145 300
# 129 300
# 186 300
# 396 300
# 364 300
# 138 300
# 195 300
# 249 300
# 149 300
# 62 300
# 79 300
# 324 300
# 115 300
# 241 300
# 132 300
# 9 300
# 191 300
# 224 300
# 530 300
# 306 300
# 224 300
# 78 300
# 440 300
# 203 300
# 196 300
# 330 300
# 33 300
# 80 300
# 177 300
# 138 300
# 86 300
# 166 300
# 59 300
# 375 300
# 218 300
# 5 300
# 385 300
# 29 300
# 291 300
# 217 300
# 118 300
# 438 300
# 624 300
# 263 300
# 247 300
# 685 300
# 286 300
# 204 300
# 332 300
# 148 300
# 106 300
# 168 300
# 120 300
# 180 300
# 392 300
# 488 300
# 211 300
# 39 300
# 167 300
# 69 300
# 184 300
# 148 300
# 175 300
# 158 300
# 127 300
# 170 300
# 288 300
# 133 300
# 234 300
# 453 300
# 185 300
# 190 300
# 134 300
# 243 300
# 252 300
# 120 300
# 110 300
# 168 300
# 120 300
# 219 300
# 45 300
# 174 300
# 123 300
# 137 300
# 19 300
# 135 300
# 316 300
# 111 300
# 125 300
# 101 300
# 115 300
# 236 300
# 114 300
# 221 300
# 290 300
# 138 300
# 196 300
# 243 300
# 118 300
# 302 300
# 221 300
# 163 300
# 108 300
# 231 300
# 113 300
# 158 300
# 177 300
# 13 300
# 105 300
# 236 300
# 186 300
# 88 300
# 13 300
# 39 300
# 389 300
# 90 300
# 295 300
# 157 300
# 427 300
# 185 300
# 308 300
# 107 300
# 32 300
# 8 300
# 176 300
# 181 300
# 124 300
# 64 300
# 174 300
# 378 300
# 450 300
# 216 300
# 204 300
# 9 300
# 223 300
# 19 300
# 215 300
# 367 300
# 391 300
# 172 300
# 265 300
# 108 300
# 269 300
# 165 300
# 478 300
# 45 300
# 203 300
# 368 300
# 176 300
# 254 300
# 320 300
# 489 300
# 5 300
# 221 300
# 293 300
# 117 300
# 365 300
# 209 300
# 258 300
# 133 300
# 239 300
# 171 300
# 340 300
# 119 300
# 153 300
# 23 300
# 87 300
# 4 300
# 43 300
# 117 300
# 409 300
# 466 300
# 213 300
# 205 300
# 300 300
# 366 300
# 114 300
# 209 300
# 256 300
# 220 300
# 85 300
# 302 300
# 260 300
# 413 300
# 373 300
# 183 300
# 219 300
# 291 300
# 293 300
# 305 300
# 218 300
# 93 300
# 116 300
# 45 300
# 758 300
# 124 300
# 122 300
# 234 300
# 271 300
# 26 300
# 75 300
# 179 300
# 150 300
# 348 300
# 123 300
# 178 300
# 255 300
# 357 300
# 612 300
# 281 300
# 262 300
# 227 300
# 310 300
# 469 300
# 302 300
# 235 300
# 202 300
# 232 300
# 107 300
# 150 300
# 275 300
# 103 300
# 136 300
# 232 300
# 129 300
# 327 300
# 210 300
# 425 300
# 240 300
# 82 300
# 271 300
# 238 300
# 258 300
# 11 300
# 44 300
# 294 300
# 45 300
# 139 300
# 272 300
# 118 300
# 191 300
# 391 300
# 161 300
# 67 300
# 451 300
# 32 300
# 253 300
# 225 300
# 158 300
# 144 300
# 223 300
# 179 300
# 111 300
# 18 300
# 129 300
# 80 300
# 441 300
# 126 300
# 9 300
# 350 300
# 429 300
# 26 300
# 100 300
# 188 300
# 47 300
# 274 300
# 253 300
# 458 300
# 316 300
# 119 300
# 180 300
# 398 300
# 183 300
# 314 300
# 172 300
# 267 300
# 632 300
# 22 300
# 102 300
# 106 300
# 79 300
# 240 300
# 302 300
# 184 300
# 215 300
# 226 300
# 155 300
# 366 300
# 353 300
# 241 300
# 523 300
# 150 300
# 319 300
# 266 300
# 466 300
# 1 300
# 188 300
# 108 300
# 196 300
# 119 300
# 182 300
# 184 300
# 67 300
# 22 300
# 253 300
# 255 300
# 199 300
# 396 300
# 122 300
# 274 300
# 111 300
# 213 300
# 39 300
# 149 300
# 31 300
# 225 300
# 279 300
# 281 300
# 169 300
# 307 300
# 222 300
# 185 300
# 437 300
# 184 300
# 7 300
# 319 300
# 130 300
# 151 300
# 75 300
# 137 300
# 138 300
# 117 300
# 189 300
# 136 300
# 211 300
# 376 300
# 162 300
# 165 300
# 120 300
# 349 300
# 380 300
# 327 300
# 64 300
# 282 300
# 141 300
# 65 300
# 14 300
# 258 300
# 19 300
# 170 300
# 466 300
# 276 300
# 296 300
# 247 300
# 287 300
# 220 300
# 166 300
# 223 300
# 138 300
# 138 300
# 203 300
# 328 300
# 162 300
# 299 300
# 160 300
# 194 300
# 8 300
# 64 300
# 58 300
# 139 300
# 187 300
# 23 300
# 395 300
# 414 300
# 114 300
# 263 300
# 260 300
# 364 300
# 110 300
# 378 300
# 260 300
# 271 300
# 147 300
# 249 300
# 145 300
# 215 300
# 221 300
# 96 300
# 112 300
# 257 300
# 214 300
# 221 300
# 141 300
# 205 300
# 208 300
# 233 300
# 215 300
# 202 300
# 484 300
# 181 300
# 89 300
# 253 300
# 94 300
# 244 300
# 156 300
# 440 300
# 291 300
# 66 300
# 305 300
# 61 300
# 386 300
# 436 300
# 18 300
# 212 300
# 148 300
# 195 300
# 114 300
# 242 300
# 284 300
# 128 300
# 399 300
# 149 300
# 93 300
# 154 300
# 125 300
# 311 300
# 451 300
# 266 300
# 374 300
# 175 300
# 237 300
# 256 300
# 108 300
# 189 300
# 191 300
# 215 300
# 123 300
# 205 300
# 243 300
# 320 300
# 115 300
# 243 300
# 397 300
# 172 300
# 126 300
# 128 300
# 370 300
# 21 300
# 248 300
# 240 300
# 219 300
# 37 300
# 336 300
# 295 300
# 149 300
# 344 300
# 267 300
# 25 300
# 516 300
# 227 300
# 246 300
# 43 300
# 340 300
# 46 300
# 243 300
# 386 300
# 333 300
# 100 300
# 55 300
# 321 300
# 148 300
# 69 300
# 171 300
# 275 300
# 93 300
# 257 300
# 121 300
# 181 300
# 250 300
# 545 300
# 194 300
# 128 300
# 73 300
# 216 300
# 121 300
# 292 300
# 262 300
# 101 300
# 305 300
# 281 300
# 600 300
# 236 300
# 101 300
# 441 300
# 121 300
# 248 300
# 132 300
# 459 300
# 235 300
# 44 300
# 565 300
# 478 300
# 221 300
# 615 300
# 197 300
# 222 300
# 193 300
# 179 300
# 386 300
# 268 300
# 256 300
# 201 300
# 198 300
# 173 300
# 165 300
# 116 300
# 162 300
# 339 300
# 161 300
# 171 300
# 422 300
# 266 300
# 182 300
# 91 300
# 319 300
# 348 300
# 52 300
# 223 300
# 250 300
# 217 300
# 20 300
# 168 300
# 62 300
# 73 300
# 452 300
# 85 300
# 113 300
# 3 300
# 103 300
# 83 300
# 240 300
# 322 300
# 102 300
# 229 300
# 249 300
# 230 300
# 520 300
# 19 300
# 184 300
# 499 300
# 159 300
# 106 300
# 98 300
# 221 300
# 201 300
# 157 300
# 364 300
# 343 300
# 6 300
# 150 300
# 210 300
# 3 300
# 284 300
# 174 300
# 99 300
# 265 300
# 86 300
# 107 300
# 101 300
# 172 300
# 36 300
# 248 300
# 132 300
# 206 300
# 579 300
# 321 300
# 177 300
# 486 300
# 173 300
# 392 300
# 392 300
# 557 300
# 203 300
# 425 300
# 64 300
# 119 300
# 57 300
# 152 300
# 122 300
# 72 300
# 198 300
# 308 300
# 231 300
# 188 300
# 101 300
# 200 300
# 347 300
# 221 300
# 96 300
# 182 300
# 347 300
# 141 300
# 272 300
# 369 300
# 193 300
# 153 300
# 232 300
# 548 300
# 60 300
# 392 300
# 260 300
# 244 300
# 347 300
# 57 300
# 241 300
# 155 300
# 460 300
# 11 300
# 180 300
# 202 300
# 413 300
# 179 300
# 245 300
# 265 300
# 344 300
# 344 300
# 184 300
# 161 300
# 466 300
# 180 300
# 355 300
# 199 300
# 188 300
# 193 300
# 215 300
# 253 300
# 206 300
# 167 300
# 88 300
# 155 300
# 9 300
# 157 300
# 188 300
# 15 300
# 144 300
# 196 300
# 255 300
# 92 300
# 90 300
# 194 300
# 25 300
# 263 300
# 89 300
# 320 300
# 149 300
# 296 300
# 121 300
# 274 300
# 67 300
# 192 300
# 261 300
# 279 300
# 194 300
# 235 300
# 22 300
# 448 300
# 149 300
# 161 300
# 130 300
# 418 300
# 47 300
# 166 300
# 116 300
# 261 300
# 170 300
# 234 300
# 229 300
# 109 300
# 62 300
# 298 300
# 184 300
# 269 300
# 97 300
# 446 300
# 75 300
# 71 300
# 285 300
# 74 300
# 73 300
# 127 300
# 532 300
# 223 300
# 94 300
# 266 300
# 352 300
# 211 300
# 157 300
# 61 300
# 205 300
# 179 300
# 458 300
# 139 300
# 108 300
# 155 300
# 157 300
# 163 300
# 16 300
# 192 300
# 123 300
# 283 300
# 199 300
# 174 300
# 127 300
# 93 300
# 393 300
# 316 300
# 22 300
# 79 300
# 161 300
# 100 300
# 372 300
# 245 300
# 217 300
# 372 300
# 281 300
# 277 300
# 95 300
# 155 300
# 164 300
# 318 300
# 332 300
# 29 300
# 152 300
# 263 300
# 132 300
# 165 300
# 146 300
# 263 300
# 287 300
# 174 300
# 235 300
# 91 300
# 216 300
# 315 300
# 314 300
# 294 300
# 95 300
# 108 300
# 55 300
# 100 300
# 299 300
# 440 300
# 137 300
# 111 300
# 138 300
# 207 300
# 286 300
# 409 300
# 46 300
# 181 300
# 48 300
# 5 300
# 114 300
# 81 300
# 360 300
# 196 300
# 146 300
# 21 300
# 165 300
# 132 300
# 240 300
# 152 300
# 259 300
# 111 300
# 215 300
# 117 300
# 44 300
# 305 300
# 496 300
# 221 300
# 165 300
# 459 300
# 110 300
# 343 300
# 172 300
# 169 300
# 112 300
# 498 300
# 198 300
# 473 300
# 105 300
# 73 300
# 243 300
# 16 300
# 12 300
# 556 300
# 249 300
# 220 300
# 166 300
# 347 300
# 172 300
# 14 300
# 107 300
# 203 300
# 141 300
# 171 300
# 104 300
# 146 300
# 203 300
# 233 300
# 269 300
# 408 300
# 162 300
# 323 300
# 126 300
# 284 300
# 172 300
# 274 300
# 243 300
# 140 300
# 439 300
# 163 300
# 354 300
# 139 300
# 77 300
# 89 300
# 243 300
# 115 300
# 404 300
# 197 300
# 287 300
# 298 300
# 204 300
# 159 300
# 44 300
# 8 300
# 20 300
# 284 300
# 49 300
# 168 300
# 307 300
# 105 300
# 278 300
# 240 300
# 309 300
# 122 300
# 49 300
# 185 300
# 319 300
# 8 300
# 220 300
# 242 300
# 67 300
# 102 300
# 54 300
# 15 300
# 399 300
# 556 300
# 207 300
# 69 300
# 89 300
# 200 300
# 124 300
# 232 300
# 71 300
# 112 300
# 50 300
# 189 300
# 421 300
# 110 300
# 172 300
# 214 300
# 128 300
# 204 300
# 153 300
# 478 300
# 314 300
# 339 300
# 312 300
# 133 300
# 349 300
# 232 300
# 46 300
# 24 300
# 177 300
# 392 300
# 241 300
# 114 300
# 163 300
# 148 300
# 237 300
# 488 300
# 238 300
# 176 300
# 28 300
# 8 300
# 130 300
# 230 300
# 37 300
# 300 300
# 404 300
# 324 300
# 22 300
# 72 300
# 466 300
# 122 300
# 96 300
# 100 300
# 294 300
# 256 300
# 357 300
# 145 300
# 197 300
# 262 300
# 234 300
# 10 300
# 345 300
# 126 300
# 235 300
# 27 300
# 177 300
# 186 300
# 234 300
# 102 300
# 80 300
# 101 300
# 138 300
# 12 300
# 461 300
# 48 300
# 321 300
# 224 300
# 143 300
# 352 300
# 220 300
# 30 300
# 472 300
# 143 300
# 133 300
# 226 300
# 101 300
# 19 300
# 116 300
# 101 300
# 147 300
# 134 300
# 187 300
# 170 300
# 14 300
# 218 300
# 238 300
# 183 300
# 38 300
# 188 300
# 63 300
# 302 300
# 229 300
# 314 300
# 126 300
# 14 300
# 170 300
# 218 300
# 135 300
# 206 300
# 36 300
# 272 300
# 142 300
# 81 300
# 128 300
# 83 300
# 193 300
# 504 300
# 236 300
# 236 300
# 15 300
# 340 300
# 206 300
# 10 300
# 234 300
# 86 300
# 161 300
# 135 300
# 130 300
# 343 300
# 164 300
# 165 300
# 157 300
# 166 300
# 191 300
# 255 300
# 127 300
# 365 300
# 26 300
# 17 300
# 229 300
# 613 300
# 16 300
# 414 300
# 348 300
# 530 300
# 173 300
# 162 300
# 110 300
# 207 300
# 294 300
# 281 300
# 223 300
# 164 300
# 104 300
# 274 300
# 205 300
# 146 300
# 270 300
# 310 300
# 209 300
# 133 300
# 9 300
# 72 300
# 299 300
# 370 300
# 119 300
# 79 300
# 42 300
# 390 300
# 68 300
# 266 300
# 218 300
# 217 300
# 187 300
# 332 300
# 87 300
# 274 300
# 503 300
# 326 300
# 215 300
# 331 300
# 218 300
# 220 300
# 466 300
# 89 300
# 62 300
# 87 300
# 51 300
# 25 300
# 106 300
# 157 300
# 437 300
# 202 300
# 113 300
# 30 300
# 74 300
# 347 300
# 304 300
# 149 300
# 107 300
# 260 300
# 88 300
# 119 300
# 376 300
# 160 300
# 284 300
# 275 300
# 442 300
# 355 300
# 59 300
# 183 300
# 210 300
# 169 300
# 446 300
# 279 300
# 197 300
# 281 300
# 238 300
# 165 300
# 181 300
# 68 300
# 267 300
# 287 300
# 494 300
# 169 300
# 185 300
# 103 300
# 407 300
# 133 300
# 144 300
# 179 300
# 17 300
# 276 300
# 157 300
# 239 300
# 176 300
# 120 300
# 154 300
# 98 300
# 42 300
# 301 300
# 539 300
# 201 300
# 138 300
# 104 300
# 41 300
# 99 300
# 511 300
# 186 300
# 26 300
# 85 300
# 396 300
# 269 300
# 295 300
# 192 300
# 182 300
# 209 300
# 140 300
# 326 300
# 206 300
# 415 300
# 175 300
# 285 300
# 193 300
# 217 300
# 171 300
# 126 300
# 250 300
# 245 300
# 107 300
# 645 300
# 189 300
# 76 300
# 91 300
# 46 300
# 228 300
# 150 300
# 229 300
# 308 300
# 170 300
# 196 300
# 633 300
# 179 300
# 281 300
# 24 300
# 78 300
# 305 300
# 104 300
# 113 300
# 589 300
# 199 300
# 128 300
# 32 300
# 358 300
# 340 300
# 145 300
# 15 300
# 98 300
# 367 300
# 471 300
# 271 300
# 48 300
# 242 300
# 151 300
# 240 300
# 135 300
# 10 300
# 154 300
# 76 300
# 254 300
# 363 300
# 163 300
# 67 300
# 309 300
# 11 300
# 680 300
# 8 300
# 59 300
# 93 300
# 46 300
# 298 300
# 271 300
# 217 300
# 158 300
# 58 300
# 230 300
# 205 300
# 435 300
# 102 300
# 121 300
# 171 300
# 109 300
# 10 300
# 264 300
# 78 300
# 233 300
# 76 300
# 172 300
# 85 300
# 182 300
# 213 300
# 118 300
# 420 300
# 238 300
# 211 300
# 231 300
# 70 300
# 210 300
# 275 300
# 97 300
# 239 300
# 342 300
# 283 300
# 212 300
# 170 300
# 315 300
# 329 300
# 106 300
# 279 300
# 330 300
# 171 300
# 211 300
# 270 300
# 234 300
# 432 300
# 181 300
# 93 300
# 41 300
# 109 300
# 232 300
# 259 300
# 91 300
# 295 300
# 205 300
# 82 300
# 41 300
# 407 300
# 150 300
# 179 300
# 119 300
# 210 300
# 161 300
# 36 300
# 239 300
# 236 300
# 479 300
# 206 300
# 9 300
# 156 300
# 204 300
# 190 300
# 126 300
# 404 300
# 275 300
# 337 300
# 387 300
# 14 300
# 164 300
# 366 300
# 264 300
# 69 300
# 18 300
# 56 300
# 358 300
# 469 300
# 178 300
# 137 300
# 324 300
# 169 300
# 75 300
# 94 300
# 164 300
# 15 300
# 151 300
# 131 300
# 138 300
# 104 300
# 293 300
# 102 300
# 148 300
# 387 300
# 205 300
# 225 300
# 279 300
# 262 300
# 196 300
# 108 300
# 118 300
# 174 300
# 638 300
# 151 300
# 327 300
# 59 300
# 71 300
# 355 300
# 285 300
# 27 300
# 237 300
# 120 300
# 197 300
# 233 300
# 262 300
# 8 300
# 149 300
# 358 300
# 121 300
# 207 300
# 189 300
# 19 300
# 68 300
# 98 300
# 211 300
# 96 300
# 7 300
# 183 300
# 377 300
# 213 300
# 194 300
# 69 300
# 52 300
# 16 300
# 373 300
# 207 300
# 172 300
# 245 300
# 454 300
# 398 300
# 275 300
# 125 300
# 417 300
# 286 300
# 144 300
# 192 300
# 164 300
# 98 300
# 70 300
# 14 300
# 297 300
# 192 300
# 173 300
# 216 300
# 303 300
# 211 300
# 172 300
# 102 300
# 284 300
# 356 300
# 402 300
# 165 300
# 7 300
# 155 300
# 206 300
# 253 300
# 379 300
# 25 300
# 146 300
# 195 300
# 350 300
# 268 300
# 164 300
# 103 300
# 95 300
# 150 300
# 77 300
# 280 300
# 171 300
# 116 300
# 680 300
# 122 300
# 236 300
# 88 300
# 618 300
# 246 300
# 86 300
# 116 300
# 261 300
# 135 300
# 102 300
# 18 300
# 317 300
# 629 300
# 84 300
# 146 300
# 187 300
# 286 300
# 541 300
# 12 300
# 108 300
# 231 300
# 201 300
# 169 300
# 134 300
# 473 300
# 303 300
# 14 300
# 282 300
# 162 300
# 10 300
# 241 300
# 186 300
# 341 300
# 436 300
# 250 300
# 60 300
# 119 300
# 176 300
# 299 300
# 126 300
# 389 300
# 263 300
# 288 300
# 422 300
# 356 300
# 245 300
# 235 300
# 231 300
# 146 300
# 157 300
# 182 300
# 143 300
# 2 300
# 250 300
# 190 300
# 162 300

# %%
# Instantiate and fit a basic Random Forest model on top of the vectors
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())
# Out:
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\ensemble\forest.py:487: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_store_unique_indices = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\tree\tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect_avg)
# Out:
# C:\Users\ssingh\.conda\envs\pytorchenv\lib\site-packages\sklearn\ensemble\base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)

# %%
from sklearn.metrics import precision_score, recall_score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.904 / Recall: 0.252 / Accuracy: 0.928
